# %% [markdown]
# Test notebook

# %%
# Dependencies and Setup
import missingno as msno
import pandas as pd
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
from scipy import stats
from scipy.stats import linregress
import scipy.stats as st
import sys
import json
import requests

# Load the data file, read and display it with Pandas
q037_data = Path("Q037.csv")

# Read and store into Pandas DataFrames
q037_df = pd.read_csv(q037_data)
q037_df.head()
# Out:
# /var/folders/vf/fx_p1h7d1tz18tzk1bj4b9nw0000gn/T/ipykernel_78926/3339273294.py:19: DtypeWarning: Columns (17,18,19,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   q037_df = pd.read_csv(q037_data)
#    YearStart  YearEnd LocationAbbr    LocationDesc  \
# 0       2021     2021           FL         Florida
# 1       2018     2018           VI  Virgin Islands
# 2       2017     2017           VI  Virgin Islands
# 3       2018     2018           AL         Alabama
# 4       2016     2016           AL         Alabama
#
#                                    Datasource                    Class  \
# 0  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 4  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
#
#                      Topic                                           Question  \
# 0  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 1  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 2  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 3  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 4  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
#
#    Data_Value_Unit Data_Value_Type  ...  \
# 0              NaN           Value  ...
# 1              NaN           Value  ...
# 2              NaN           Value  ...
# 3              NaN           Value  ...
# 4              NaN           Value  ...
#
#                                 GeoLocation  ClassID TopicID QuestionID  \
# 0  (28.932040377000476, -81.92896053899966)      OWS    OWS1       Q037
# 1                   (18.335765, -64.896335)      OWS    OWS1       Q037
# 2                   (18.335765, -64.896335)      OWS    OWS1       Q037
# 3   (32.84057112200048, -86.63186076199969)      OWS    OWS1       Q037
# 4             (32.840571122, -86.631860762)      OWS    OWS1       Q037
#
#    DataValueTypeID  LocationID  StratificationCategory1 Stratification1  \
# 0            VALUE          12                    Total           Total
# 1            VALUE          78                    Total           Total
# 2            VALUE          78                    Total           Total
# 3            VALUE           1                    Total           Total
# 4            VALUE           1                    Total           Total
#
#   StratificationCategoryId1 StratificationID1
# 0                       OVR           OVERALL
# 1                       OVR           OVERALL
# 2                       OVR           OVERALL
# 3                       OVR           OVERALL
# 4                       OVR           OVERALL
#
# [5 rows x 33 columns]

# %%
q037_df.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'Datasource',
#        'Class', 'Topic', 'Question', 'Data_Value_Unit', 'Data_Value_Type',
#        'Data_Value', 'Data_Value_Alt', 'Data_Value_Footnote_Symbol',
#        'Data_Value_Footnote', 'Low_Confidence_Limit', 'High_Confidence_Limit ',
#        'Sample_Size', 'Total', 'Age(years)', 'Education', 'Gender', 'Income',
#        'Race/Ethnicity', 'GeoLocation', 'ClassID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'LocationID', 'StratificationCategory1',
#        'Stratification1', 'StratificationCategoryId1', 'StratificationID1'],
#       dtype='object')

# %%
# Trim the columns of data to the one we need
q037_df_trim = q037_df.drop(['Datasource','Class', 'Topic','Data_Value_Unit', 'Data_Value_Type','Data_Value_Alt','Data_Value_Footnote_Symbol','Data_Value_Footnote','Total', 'DataValueTypeID'], axis=1)
q037_df_trim
# Out:
#        YearStart  YearEnd LocationAbbr    LocationDesc  \
# 0           2021     2021           FL         Florida
# 1           2018     2018           VI  Virgin Islands
# 2           2017     2017           VI  Virgin Islands
# 3           2018     2018           AL         Alabama
# 4           2016     2016           AL         Alabama
# ...          ...      ...          ...             ...
# 18112       2021     2021           WY         Wyoming
# 18113       2022     2022           WY         Wyoming
# 18114       2022     2022           WY         Wyoming
# 18115       2022     2022           WY         Wyoming
# 18116       2019     2019           NJ      New Jersey
#
#                                                 Question  Data_Value  \
# 0      Percent of adults aged 18 years and older who ...         NaN
# 1      Percent of adults aged 18 years and older who ...         NaN
# 2      Percent of adults aged 18 years and older who ...         NaN
# 3      Percent of adults aged 18 years and older who ...        33.4
# 4      Percent of adults aged 18 years and older who ...        33.9
# ...                                                  ...         ...
# 18112  Percent of adults aged 18 years and older who ...        36.6
# 18113  Percent of adults aged 18 years and older who ...        29.2
# 18114  Percent of adults aged 18 years and older who ...        26.5
# 18115  Percent of adults aged 18 years and older who ...        36.9
# 18116  Percent of adults aged 18 years and older who ...         NaN
#
#        Low_Confidence_Limit  High_Confidence_Limit   Sample_Size Age(years)  \
# 0                       NaN                     NaN          NaN        NaN
# 1                       NaN                     NaN          NaN        NaN
# 2                       NaN                     NaN          NaN        NaN
# 3                      31.9                    35.0       6144.0        NaN
# 4                      32.3                    35.4       6526.0        NaN
# ...                     ...                     ...          ...        ...
# 18112                  34.3                    38.9       3555.0        NaN
# 18113                  17.8                    44.0         58.0        NaN
# 18114                  19.9                    34.3        200.0        NaN
# 18115                  34.9                    38.9       3356.0        NaN
# 18116                   NaN                     NaN          NaN        NaN
#
#        ...                 Race/Ethnicity  \
# 0      ...                            NaN
# 1      ...                            NaN
# 2      ...                            NaN
# 3      ...                            NaN
# 4      ...                            NaN
# ...    ...                            ...
# 18112  ...             Non-Hispanic White
# 18113  ...  American Indian/Alaska Native
# 18114  ...                       Hispanic
# 18115  ...             Non-Hispanic White
# 18116  ...                            NaN
#
#                                     GeoLocation ClassID TopicID QuestionID  \
# 0      (28.932040377000476, -81.92896053899966)     OWS    OWS1       Q037
# 1                       (18.335765, -64.896335)     OWS    OWS1       Q037
# 2                       (18.335765, -64.896335)     OWS    OWS1       Q037
# 3       (32.84057112200048, -86.63186076199969)     OWS    OWS1       Q037
# 4                 (32.840571122, -86.631860762)     OWS    OWS1       Q037
# ...                                         ...     ...     ...        ...
# 18112  (43.23554134300048, -108.10983035299967)     OWS    OWS1       Q037
# 18113  (43.23554134300048, -108.10983035299967)     OWS    OWS1       Q037
# 18114  (43.23554134300048, -108.10983035299967)     OWS    OWS1       Q037
# 18115  (43.23554134300048, -108.10983035299967)     OWS    OWS1       Q037
# 18116   (40.13057004800049, -74.27369128799967)     OWS    OWS1       Q037
#
#       LocationID StratificationCategory1                Stratification1  \
# 0             12                   Total                          Total
# 1             78                   Total                          Total
# 2             78                   Total                          Total
# 3              1                   Total                          Total
# 4              1                   Total                          Total
# ...          ...                     ...                            ...
# 18112         56          Race/Ethnicity             Non-Hispanic White
# 18113         56          Race/Ethnicity  American Indian/Alaska Native
# 18114         56          Race/Ethnicity                       Hispanic
# 18115         56          Race/Ethnicity             Non-Hispanic White
# 18116         34                     NaN                            NaN
#
#        StratificationCategoryId1 StratificationID1
# 0                            OVR           OVERALL
# 1                            OVR           OVERALL
# 2                            OVR           OVERALL
# 3                            OVR           OVERALL
# 4                            OVR           OVERALL
# ...                          ...               ...
# 18112                       RACE           RACEWHT
# 18113                       RACE           RACENAA
# 18114                       RACE           RACEHIS
# 18115                       RACE           RACEWHT
# 18116                        NaN               NaN
#
# [18117 rows x 23 columns]

# %%
# Remove the names of the territories
q037_df_trim_filtered = q037_df_trim[~q037_df_trim['LocationDesc'].str.contains('Guam|Virgin Islands|Puerto Rico')]

#remove NA Data value
q037_df_trim_cleaned = q037_df_trim_filtered.dropna(subset=['Data_Value'])
q037_df_trim_cleaned
# Out:
#        YearStart  YearEnd LocationAbbr LocationDesc  \
# 3           2018     2018           AL      Alabama
# 4           2016     2016           AL      Alabama
# 5           2020     2020           AL      Alabama
# 6           2017     2017           AL      Alabama
# 7           2011     2011           AL      Alabama
# ...          ...      ...          ...          ...
# 18111       2021     2021           WY      Wyoming
# 18112       2021     2021           WY      Wyoming
# 18113       2022     2022           WY      Wyoming
# 18114       2022     2022           WY      Wyoming
# 18115       2022     2022           WY      Wyoming
#
#                                                 Question  Data_Value  \
# 3      Percent of adults aged 18 years and older who ...        33.4
# 4      Percent of adults aged 18 years and older who ...        33.9
# 5      Percent of adults aged 18 years and older who ...        33.7
# 6      Percent of adults aged 18 years and older who ...        33.9
# 7      Percent of adults aged 18 years and older who ...        34.7
# ...                                                  ...         ...
# 18111  Percent of adults aged 18 years and older who ...        51.4
# 18112  Percent of adults aged 18 years and older who ...        36.6
# 18113  Percent of adults aged 18 years and older who ...        29.2
# 18114  Percent of adults aged 18 years and older who ...        26.5
# 18115  Percent of adults aged 18 years and older who ...        36.9
#
#        Low_Confidence_Limit  High_Confidence_Limit   Sample_Size Age(years)  \
# 3                      31.9                    35.0       6144.0        NaN
# 4                      32.3                    35.4       6526.0        NaN
# 5                      32.0                    35.5       4973.0        NaN
# 6                      32.3                    35.5       6245.0        NaN
# 7                      33.1                    36.3       7304.0        NaN
# ...                     ...                     ...          ...        ...
# 18111                  34.6                    67.9         54.0        NaN
# 18112                  34.3                    38.9       3555.0        NaN
# 18113                  17.8                    44.0         58.0        NaN
# 18114                  19.9                    34.3        200.0        NaN
# 18115                  34.9                    38.9       3356.0        NaN
#
#        ...                 Race/Ethnicity  \
# 3      ...                            NaN
# 4      ...                            NaN
# 5      ...                            NaN
# 6      ...                            NaN
# 7      ...                            NaN
# ...    ...                            ...
# 18111  ...                2 or more races
# 18112  ...             Non-Hispanic White
# 18113  ...  American Indian/Alaska Native
# 18114  ...                       Hispanic
# 18115  ...             Non-Hispanic White
#
#                                     GeoLocation ClassID TopicID QuestionID  \
# 3       (32.84057112200048, -86.63186076199969)     OWS    OWS1       Q037
# 4                 (32.840571122, -86.631860762)     OWS    OWS1       Q037
# 5       (32.84057112200048, -86.63186076199969)     OWS    OWS1       Q037
# 6                 (32.840571122, -86.631860762)     OWS    OWS1       Q037
# 7                 (32.840571122, -86.631860762)     OWS    OWS1       Q037
# ...                                         ...     ...     ...        ...
# 18111  (43.23554134300048, -108.10983035299967)     OWS    OWS1       Q037
# 18112  (43.23554134300048, -108.10983035299967)     OWS    OWS1       Q037
# 18113  (43.23554134300048, -108.10983035299967)     OWS    OWS1       Q037
# 18114  (43.23554134300048, -108.10983035299967)     OWS    OWS1       Q037
# 18115  (43.23554134300048, -108.10983035299967)     OWS    OWS1       Q037
#
#       LocationID StratificationCategory1                Stratification1  \
# 3              1                   Total                          Total
# 4              1                   Total                          Total
# 5              1                   Total                          Total
# 6              1                   Total                          Total
# 7              1                   Total                          Total
# ...          ...                     ...                            ...
# 18111         56          Race/Ethnicity                2 or more races
# 18112         56          Race/Ethnicity             Non-Hispanic White
# 18113         56          Race/Ethnicity  American Indian/Alaska Native
# 18114         56          Race/Ethnicity                       Hispanic
# 18115         56          Race/Ethnicity             Non-Hispanic White
#
#        StratificationCategoryId1 StratificationID1
# 3                            OVR           OVERALL
# 4                            OVR           OVERALL
# 5                            OVR           OVERALL
# 6                            OVR           OVERALL
# 7                            OVR           OVERALL
# ...                          ...               ...
# 18111                       RACE         RACE2PLUS
# 18112                       RACE           RACEWHT
# 18113                       RACE           RACENAA
# 18114                       RACE           RACEHIS
# 18115                       RACE           RACEWHT
#
# [15836 rows x 23 columns]

# %%
#filter only National data
q037_natl_df = q037_df_trim_cleaned[q037_df_trim_cleaned['LocationDesc'].str.contains('National')].sort_values(by=['YearStart', 'Stratification1'])
q037_natl_df
# Out:
#        YearStart  YearEnd LocationAbbr LocationDesc  \
# 10772       2011     2011           US     National
# 10759       2011     2011           US     National
# 10802       2011     2011           US     National
# 10786       2011     2011           US     National
# 10796       2011     2011           US     National
# ...          ...      ...          ...          ...
# 7794        2022     2022           US     National
# 16491       2022     2022           US     National
# 16555       2022     2022           US     National
# 5916        2022     2022           US     National
# 339         2022     2022           US     National
#
#                                                 Question  Data_Value  \
# 10772  Percent of adults aged 18 years and older who ...        34.5
# 10759  Percent of adults aged 18 years and older who ...        35.5
# 10802  Percent of adults aged 18 years and older who ...        37.1
# 10786  Percent of adults aged 18 years and older who ...        37.5
# 10796  Percent of adults aged 18 years and older who ...        38.3
# ...                                                  ...         ...
# 7794   Percent of adults aged 18 years and older who ...        38.9
# 16491  Percent of adults aged 18 years and older who ...        31.6
# 16555  Percent of adults aged 18 years and older who ...        34.5
# 5916   Percent of adults aged 18 years and older who ...        33.6
# 339    Percent of adults aged 18 years and older who ...        34.1
#
#        Low_Confidence_Limit  High_Confidence_Limit   Sample_Size Age(years)  \
# 10772                  33.8                    35.2      74022.0        NaN
# 10759                  34.6                    36.4      48923.0        NaN
# 10802                  36.3                    37.9      61329.0        NaN
# 10786                  36.8                    38.3      64664.0        NaN
# 10796                  37.8                    38.9     110079.0        NaN
# ...                     ...                     ...          ...        ...
# 7794                   38.5                    39.4     189865.0        NaN
# 16491                  30.6                    32.6      29914.0        NaN
# 16555                  34.2                    34.8     289595.0        NaN
# 5916                   33.0                    34.2     105991.0        NaN
# 339                    33.8                    34.4     387549.0        NaN
#
#        ...      Race/Ethnicity GeoLocation ClassID TopicID QuestionID  \
# 10772  ...                 NaN         NaN     OWS    OWS1       Q037
# 10759  ...                 NaN         NaN     OWS    OWS1       Q037
# 10802  ...                 NaN         NaN     OWS    OWS1       Q037
# 10786  ...                 NaN         NaN     OWS    OWS1       Q037
# 10796  ...                 NaN         NaN     OWS    OWS1       Q037
# ...    ...                 ...         ...     ...     ...        ...
# 7794   ...                 NaN         NaN     OWS    OWS1       Q037
# 16491  ...  Non-Hispanic Black         NaN     OWS    OWS1       Q037
# 16555  ...  Non-Hispanic White         NaN     OWS    OWS1       Q037
# 5916   ...                 NaN         NaN     OWS    OWS1       Q037
# 339    ...                 NaN         NaN     OWS    OWS1       Q037
#
#       LocationID StratificationCategory1                   Stratification1  \
# 10772         59                  Income                 $15,000 - $24,999
# 10759         59                  Income                 $25,000 - $34,999
# 10802         59                  Income                 $35,000 - $49,999
# 10786         59                  Income                 $50,000 - $74,999
# 10796         59                  Income                $75,000 or greater
# ...          ...                     ...                               ...
# 7794          59                  Gender                              Male
# 16491         59          Race/Ethnicity                Non-Hispanic Black
# 16555         59          Race/Ethnicity                Non-Hispanic White
# 5916          59               Education  Some college or technical school
# 339           59                   Total                             Total
#
#        StratificationCategoryId1 StratificationID1
# 10772                        INC           INC1525
# 10759                        INC           INC2535
# 10802                        INC           INC3550
# 10786                        INC           INC5075
# 10796                        INC         INC75PLUS
# ...                          ...               ...
# 7794                         GEN              MALE
# 16491                       RACE           RACEBLK
# 16555                       RACE           RACEWHT
# 5916                         EDU          EDUCOTEC
# 339                          OVR           OVERALL
#
# [335 rows x 23 columns]

# %%
q037_df_sorted = q037_df_trim_cleaned.sort_values(by=['YearStart', 'StratificationCategory1', 'Stratification1', 'LocationDesc'])
q037_df_sorted
# Out:
#      YearStart  YearEnd LocationAbbr   LocationDesc  \
# 704       2011     2011           AL        Alabama
# 771       2011     2011           AK         Alaska
# 863       2011     2011           AZ        Arizona
# 899       2011     2011           AR       Arkansas
# 994       2011     2011           CA     California
# ..         ...      ...          ...            ...
# 598       2022     2022           VA       Virginia
# 610       2022     2022           WA     Washington
# 622       2022     2022           WV  West Virginia
# 634       2022     2022           WI      Wisconsin
# 646       2022     2022           WY        Wyoming
#
#                                               Question  Data_Value  \
# 704  Percent of adults aged 18 years and older who ...        27.1
# 771  Percent of adults aged 18 years and older who ...        32.0
# 863  Percent of adults aged 18 years and older who ...        27.7
# 899  Percent of adults aged 18 years and older who ...        27.3
# 994  Percent of adults aged 18 years and older who ...        26.8
# ..                                                 ...         ...
# 598  Percent of adults aged 18 years and older who ...        32.1
# 610  Percent of adults aged 18 years and older who ...        34.6
# 622  Percent of adults aged 18 years and older who ...        33.4
# 634  Percent of adults aged 18 years and older who ...        33.0
# 646  Percent of adults aged 18 years and older who ...        35.6
#
#      Low_Confidence_Limit  High_Confidence_Limit   Sample_Size Age(years)  \
# 704                  21.6                    33.3        356.0    18 - 24
# 771                  24.7                    40.4        212.0    18 - 24
# 863                  20.7                    36.1        212.0    18 - 24
# 899                  19.6                    36.7        136.0    18 - 24
# 994                  23.6                    30.3        902.0    18 - 24
# ..                    ...                     ...          ...        ...
# 598                  30.8                    33.5       9378.0        NaN
# 610                  33.7                    35.4      22869.0        NaN
# 622                  31.7                    35.1       4640.0        NaN
# 634                  31.7                    34.2      10080.0        NaN
# 646                  33.7                    37.6       3799.0        NaN
#
#      ... Race/Ethnicity                               GeoLocation ClassID  \
# 704  ...            NaN             (32.840571122, -86.631860762)     OWS
# 771  ...            NaN         (64.845079957001, -147.722059036)     OWS
# 863  ...            NaN             (34.86597028, -111.763811277)     OWS
# 899  ...            NaN             (34.748650124, -92.274490743)     OWS
# 994  ...            NaN            (37.638640123, -120.999999538)     OWS
# ..   ...            ...                                       ...     ...
# 598  ...            NaN   (37.54268067400045, -78.45789046299967)     OWS
# 610  ...            NaN  (47.52227862900048, -120.47001078999972)     OWS
# 622  ...            NaN   (38.66551020200046, -80.71264013499967)     OWS
# 634  ...            NaN   (44.39319117400049, -89.81637074199966)     OWS
# 646  ...            NaN  (43.23554134300048, -108.10983035299967)     OWS
#
#     TopicID QuestionID LocationID StratificationCategory1 Stratification1  \
# 704    OWS1       Q037          1             Age (years)         18 - 24
# 771    OWS1       Q037          2             Age (years)         18 - 24
# 863    OWS1       Q037          4             Age (years)         18 - 24
# 899    OWS1       Q037          5             Age (years)         18 - 24
# 994    OWS1       Q037          6             Age (years)         18 - 24
# ..      ...        ...        ...                     ...             ...
# 598    OWS1       Q037         51                   Total           Total
# 610    OWS1       Q037         53                   Total           Total
# 622    OWS1       Q037         54                   Total           Total
# 634    OWS1       Q037         55                   Total           Total
# 646    OWS1       Q037         56                   Total           Total
#
#      StratificationCategoryId1 StratificationID1
# 704                      AGEYR         AGEYR1824
# 771                      AGEYR         AGEYR1824
# 863                      AGEYR         AGEYR1824
# 899                      AGEYR         AGEYR1824
# 994                      AGEYR         AGEYR1824
# ..                         ...               ...
# 598                        OVR           OVERALL
# 610                        OVR           OVERALL
# 622                        OVR           OVERALL
# 634                        OVR           OVERALL
# 646                        OVR           OVERALL
#
# [15836 rows x 23 columns]

# %% [markdown]
# # Visualizations focus on a specific year, i.e., 2022

# %%
q037_2022 = q037_df_sorted.loc[q037_df_sorted["YearStart"] == 2022]
q037_2022
# Out:
#       YearStart  YearEnd LocationAbbr   LocationDesc  \
# 732        2022     2022           AL        Alabama
# 803        2022     2022           AK         Alaska
# 880        2022     2022           AZ        Arizona
# 948        2022     2022           AR       Arkansas
# 1023       2022     2022           CA     California
# ...         ...      ...          ...            ...
# 598        2022     2022           VA       Virginia
# 610        2022     2022           WA     Washington
# 622        2022     2022           WV  West Virginia
# 634        2022     2022           WI      Wisconsin
# 646        2022     2022           WY        Wyoming
#
#                                                Question  Data_Value  \
# 732   Percent of adults aged 18 years and older who ...        31.0
# 803   Percent of adults aged 18 years and older who ...        27.7
# 880   Percent of adults aged 18 years and older who ...        22.7
# 948   Percent of adults aged 18 years and older who ...        24.8
# 1023  Percent of adults aged 18 years and older who ...        25.4
# ...                                                 ...         ...
# 598   Percent of adults aged 18 years and older who ...        32.1
# 610   Percent of adults aged 18 years and older who ...        34.6
# 622   Percent of adults aged 18 years and older who ...        33.4
# 634   Percent of adults aged 18 years and older who ...        33.0
# 646   Percent of adults aged 18 years and older who ...        35.6
#
#       Low_Confidence_Limit  High_Confidence_Limit   Sample_Size Age(years)  \
# 732                   23.5                    39.7        182.0    18 - 24
# 803                   22.5                    33.5        324.0    18 - 24
# 880                   18.1                    28.1        481.0    18 - 24
# 948                   18.8                    31.8        219.0    18 - 24
# 1023                  21.9                    29.2        869.0    18 - 24
# ...                    ...                     ...          ...        ...
# 598                   30.8                    33.5       9378.0        NaN
# 610                   33.7                    35.4      22869.0        NaN
# 622                   31.7                    35.1       4640.0        NaN
# 634                   31.7                    34.2      10080.0        NaN
# 646                   33.7                    37.6       3799.0        NaN
#
#       ... Race/Ethnicity                                GeoLocation ClassID  \
# 732   ...            NaN    (32.84057112200048, -86.63186076199969)     OWS
# 803   ...            NaN   (64.84507995700051, -147.72205903599973)     OWS
# 880   ...            NaN  (34.865970280000454, -111.76381127699972)     OWS
# 948   ...            NaN    (34.74865012400045, -92.27449074299966)     OWS
# 1023  ...            NaN   (37.63864012300047, -120.99999953799971)     OWS
# ...   ...            ...                                        ...     ...
# 598   ...            NaN    (37.54268067400045, -78.45789046299967)     OWS
# 610   ...            NaN   (47.52227862900048, -120.47001078999972)     OWS
# 622   ...            NaN    (38.66551020200046, -80.71264013499967)     OWS
# 634   ...            NaN    (44.39319117400049, -89.81637074199966)     OWS
# 646   ...            NaN   (43.23554134300048, -108.10983035299967)     OWS
#
#      TopicID QuestionID LocationID StratificationCategory1 Stratification1  \
# 732     OWS1       Q037          1             Age (years)         18 - 24
# 803     OWS1       Q037          2             Age (years)         18 - 24
# 880     OWS1       Q037          4             Age (years)         18 - 24
# 948     OWS1       Q037          5             Age (years)         18 - 24
# 1023    OWS1       Q037          6             Age (years)         18 - 24
# ...      ...        ...        ...                     ...             ...
# 598     OWS1       Q037         51                   Total           Total
# 610     OWS1       Q037         53                   Total           Total
# 622     OWS1       Q037         54                   Total           Total
# 634     OWS1       Q037         55                   Total           Total
# 646     OWS1       Q037         56                   Total           Total
#
#       StratificationCategoryId1 StratificationID1
# 732                       AGEYR         AGEYR1824
# 803                       AGEYR         AGEYR1824
# 880                       AGEYR         AGEYR1824
# 948                       AGEYR         AGEYR1824
# 1023                      AGEYR         AGEYR1824
# ...                         ...               ...
# 598                         OVR           OVERALL
# 610                         OVR           OVERALL
# 622                         OVR           OVERALL
# 634                         OVR           OVERALL
# 646                         OVR           OVERALL
#
# [1315 rows x 23 columns]

# %%
# Output the
q037_2022_states_age = q037_2022.loc[q037_2022["StratificationCategoryId1"] == "AGEYR"]
q037_2022_states_age.to_csv("q037_2022_states_age.csv", index=False)

# %%
# Intend to plot into 3D ===> Failed
#######################################

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator

age_ranges = q037_2022_states_age.groupby("Stratification1")
#len(age_ranges)
states = q037_2022_states_age.groupby("LocationAbbr")
#len(states)

# Generate data
X = np.arange(len(age_ranges))
Y = np.arange(len(states))
X, Y = np.meshgrid(X, Y)
Z = q037_2022_states_age.groupby(["Stratification1","LocationAbbr"])["Data_Value"]

# Create a 3D plot
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

# Plot the surface
ax.plot_surface(X, Y, Z, cmap=cm.coolwarm, linewidth=0, antialiased=False)

# Set labels and title
ax.set_xlabel('Stratification1')
ax.set_ylabel('LocationAbbr')
ax.set_zlabel('Data_Value')
ax.set_title('3D Surface Plot')
ax.zaxis.set_major_locator(LinearLocator(10))

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 22
#      19 fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
#      21 # Plot the surface
# ---> 22 ax.plot_surface(X, Y, Z, cmap=cm.coolwarm, linewidth=0, antialiased=False)
#      24 # Set labels and title
#      25 ax.set_xlabel('Stratification1')
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/mpl_toolkits/mplot3d/axes3d.py:1569, in Axes3D.plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, **kwargs)
#    1566 had_data = self.has_data()
#    1568 if Z.ndim != 2:
# -> 1569     raise ValueError("Argument Z must be 2-dimensional.")
#    1571 Z = cbook._to_unmasked_float_array(Z)
#    1572 X, Y, Z = np.broadcast_arrays(X, Y, Z)
#
# ValueError: Argument Z must be 2-dimensional.

# %%
import matplotlib.pyplot as plt

# Create a scatter plot
plt.scatter(q037_2022_states_age["Stratification1"], q037_2022_states_age["LocationAbbr"], c=q037_2022_states_age["Data_Value"], cmap='viridis')

# Set labels and title
plt.xlabel('Stratification1')
plt.ylabel('LocationAbbr')
plt.title('Scatter Plot of Data_Value against Stratification1 and LocationAbbr')

# Add colorbar
plt.colorbar(label='Data_Value')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Group the DataFrame by 'Stratification1' and 'LocationAbbr' and calculate the median Data_Value for each group
grouped_data = q037_2022_states_age.groupby(['Stratification1', 'LocationAbbr'])['Data_Value'].median().unstack()

# Plot a bar plot for each value in 'Stratification1'
grouped_data.plot(kind='bar', figsize=(12, 6))

# Set labels and title
plt.xlabel('LocationAbbr')
plt.ylabel('Data_Value')
plt.title('Bar Plot of Data_Value vs. LocationAbbr for each Stratification1')

# Show the plot
plt.legend(title='Stratification1', bbox_to_anchor=(1, 1))
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/vf/fx_p1h7d1tz18tzk1bj4b9nw0000gn/T/ipykernel_78926/2585121566.py:17: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
# Get unique values of age range
age_ranges = q037_2022_states_age["Stratification1"].unique()

# Set the number of rows and columns for subplots
num_rows = len(age_ranges)
num_cols = 1  # Each age range will have its own subplot

# Create subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(12, 6*num_rows))

# Iterate over unique age range
for i, age in enumerate(age_ranges):
    # Filter the DataFrame for the current age range
    filtered_data = q037_2022_states_age[q037_2022_states_age["Stratification1"] == age]
    # Group by States, calculate the median Data_Value for each group, and sort in ascending order
    grouped_data = filtered_data.groupby('LocationAbbr')['Data_Value'].median().sort_values(ascending=False)

    # Plot a bar plot for the current age range value in the corresponding subplot
    ax = axes[i] if num_rows > 1 else axes
    grouped_data.plot(kind='bar', ax=ax, color=colors)
    ax.set_title(f'Age range: {age}')
    ax.set_xlabel('States')
    ax.set_ylabel('Percent (%)')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Output 
q037_2022_states_income = q037_2022.loc[q037_2022["StratificationCategoryId1"] == "INC"]
q037_2022_states_income.to_csv("q037_2022_states_income.csv", index=False)

# %%
# Get unique values of income range
income_ranges = q037_2022_states_income["Stratification1"].unique()

# Set the number of rows and columns for subplots
num_rows = len(income_ranges)
num_cols = 1  # Each income range will have its own subplot

# Create subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(12, 6*num_rows))

# Iterate over unique income range
for i, income in enumerate(income_ranges):
    # Filter the DataFrame for the current income range
    filtered_data = q037_2022_states_income[q037_2022_states_income["Stratification1"] == income]
    # Group by States, calculate the median Data_Value for each group, and sort in ascending order
    grouped_data = filtered_data.groupby('LocationAbbr')['Data_Value'].median().sort_values(ascending=False)

    # Plot a bar plot for the current income range value in the corresponding subplot
    ax = axes[i] if num_rows > 1 else axes
    grouped_data.plot(kind='bar', ax=ax, color=colors)
    ax.set_title(f'income range: {income}')
    ax.set_xlabel('States')
    ax.set_ylabel('Percent (%)')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Output 
q037_2022_states_edu = q037_2022.loc[q037_2022["StratificationCategoryId1"] == "EDU"]
q037_2022_states_edu.to_csv("q037_2022_states_edu.csv", index=False)

# %%
# Get unique values of edu range
edu_ranges = q037_2022_states_edu["Stratification1"].unique()

# Set the number of rows and columns for subplots
num_rows = len(edu_ranges)
num_cols = 1  # Each edu range will have its own subplot

# Create subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(12, 6*num_rows))

# Iterate over unique edu range
for i, edu in enumerate(edu_ranges):
    # Filter the DataFrame for the current edu range
    filtered_data = q037_2022_states_edu[q037_2022_states_edu["Stratification1"] == edu]
    # Group by States, calculate the median Data_Value for each group, and sort in ascending order
    grouped_data = filtered_data.groupby('LocationAbbr')['Data_Value'].median().sort_values(ascending=False)

    # Plot a bar plot for the current edu range value in the corresponding subplot
    ax = axes[i] if num_rows > 1 else axes
    grouped_data.plot(kind='bar', ax=ax, color=colors)
    ax.set_title(f'edu range: {edu}')
    ax.set_xlabel('States')
    ax.set_ylabel('Percent (%)')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Output 
q037_2022_states_race = q037_2022.loc[q037_2022["StratificationCategoryId1"] == "RACE"]
q037_2022_states_race.to_csv("q037_2022_states_race.csv", index=False)

# %%
# Get unique values of race range
races = q037_2022_states_race["Stratification1"].unique()

# Set the number of rows and columns for subplots
num_rows = len(races)
num_cols = 1  # Each race will have its own subplot

# Create subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(12, 6*num_rows))

# Iterate over unique race range
for i, race in enumerate(races):
    # Filter the DataFrame for the current race 
    filtered_data = q037_2022_states_race[q037_2022_states_race["Stratification1"] == race]
    # Group by States, calculate the median Data_Value for each group, and sort in ascending order
    grouped_data = filtered_data.groupby('LocationAbbr')['Data_Value'].median().sort_values(ascending=False)

    # Plot a bar plot for the current race range value in the corresponding subplot
    ax = axes[i] if num_rows > 1 else axes
    grouped_data.plot(kind='bar', ax=ax, color=colors)
    ax.set_title(f'Race/Ethnicity: {race}')
    ax.set_xlabel('States')
    ax.set_ylabel('Percent (%)')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Output 
q037_2022_states_gen = q037_2022.loc[q037_2022["StratificationCategoryId1"] == "GEN"]
q037_2022_states_gen.to_csv("q037_2022_states_gen.csv", index=False)

# %%
# Get unique values of genders
genders = q037_2022_states_gen["Stratification1"].unique()

# Set the number of rows and columns for subplots
num_rows = len(genders)
num_cols = 1  # Each gen will have its own subplot

# Create subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(12, 6*num_rows))

# Iterate over unique gender
for i, gen in enumerate(genders):
    # Filter the DataFrame for the current gen 
    filtered_data = q037_2022_states_gen[q037_2022_states_gen["Stratification1"] == gen]
    # Group by States, calculate the median Data_Value for each group, and sort in ascending order
    grouped_data = filtered_data.groupby('LocationAbbr')['Data_Value'].median().sort_values(ascending=False)

    # Plot a bar plot for the current gen range value in the corresponding subplot
    ax = axes[i] if num_rows > 1 else axes
    grouped_data.plot(kind='bar', ax=ax, color=colors)
    ax.set_title(f'Gender: {gen}')
    ax.set_xlabel('States')
    ax.set_ylabel('Percent (%)')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Get unique values of genders
strats = q037_natl_df["Stratification1"].unique()

# Set the number of rows and columns for subplots
num_rows = len(strats)
num_cols = 1  # Each gen will have its own subplot

# Create subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(12, 6*num_rows))

# Iterate over unique gender
for i, strat in enumerate(strats):
    # Filter the DataFrame for the current gen 
    filtered_data = q037_natl_df[q037_natl_df["Stratification1"] == strat]
    # Group by States, calculate the median Data_Value for each group, and sort in ascending order
    grouped_data = filtered_data.groupby('LocationAbbr')['Data_Value'].median().sort_values(ascending=False)

    # Plot a bar plot for the current gen range value in the corresponding subplot
    ax = axes[i] if num_rows > 1 else axes
    grouped_data.plot(kind='bar', ax=ax, color=colors)
    ax.set_title(f'{strat}')
    ax.set_xlabel('States')
    ax.set_ylabel('Percent (%)')

# Adjust layout
plt.tight_layout()
plt.show()
