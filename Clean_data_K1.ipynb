# %% [markdown]
# Test notebook

# %%
# Dependencies and Setup
import missingno as msno
import pandas as pd
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
from scipy import stats
from scipy.stats import linregress
import scipy.stats as st
import sys
import json
import requests

# Load the data file, read and display it with Pandas
q037_data = Path("Q037.csv")

# Read and store into Pandas DataFrames
q037_df = pd.read_csv(q037_data)
q037_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr  LocationDesc  \
# 0       2013     2013           US      National
# 1       2012     2012           WY       Wyoming
# 2       2015     2015           RI  Rhode Island
# 3       2015     2015           GU          Guam
# 4       2012     2012           US      National
#
#                                    Datasource                    Class  \
# 0  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 4  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
#
#                      Topic                                           Question  \
# 0  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 1  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 2  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 3  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 4  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
#
#    Data_Value_Unit Data_Value_Type  ...                     GeoLocation  \
# 0              NaN           Value  ...                             NaN
# 1              NaN           Value  ...  (43.235541343, -108.109830353)
# 2              NaN           Value  ...   (41.708280193, -71.522470314)
# 3              NaN           Value  ...         (13.444304, 144.793731)
# 4              NaN           Value  ...                             NaN
#
#    ClassID TopicID QuestionID  DataValueTypeID  LocationID  \
# 0      OWS    OWS1       Q037            VALUE          59
# 1      OWS    OWS1       Q037            VALUE          56
# 2      OWS    OWS1       Q037            VALUE          44
# 3      OWS    OWS1       Q037            VALUE          66
# 4      OWS    OWS1       Q037            VALUE          59
#
#    StratificationCategory1                   Stratification1  \
# 0                   Income                 Data not reported
# 1           Race/Ethnicity     American Indian/Alaska Native
# 2           Race/Ethnicity                          Hispanic
# 3           Race/Ethnicity                             Other
# 4                Education  Some college or technical school
#
#   StratificationCategoryId1 StratificationID1
# 0                       INC             INCNR
# 1                      RACE           RACENAA
# 2                      RACE           RACEHIS
# 3                      RACE           RACEOTH
# 4                       EDU          EDUCOTEC
#
# [5 rows x 33 columns]

# %%
q037_df.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'Datasource',
#        'Class', 'Topic', 'Question', 'Data_Value_Unit', 'Data_Value_Type',
#        'Data_Value', 'Data_Value_Alt', 'Data_Value_Footnote_Symbol',
#        'Data_Value_Footnote', 'Low_Confidence_Limit', 'High_Confidence_Limit ',
#        'Sample_Size', 'Total', 'Age(years)', 'Education', 'Gender', 'Income',
#        'Race/Ethnicity', 'GeoLocation', 'ClassID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'LocationID', 'StratificationCategory1',
#        'Stratification1', 'StratificationCategoryId1', 'StratificationID1'],
#       dtype='object')

# %%
# Trim the columns of data to the one we need
q037_df_trim = q037_df.drop(['Datasource','Class', 'Topic','Data_Value_Unit', 'Data_Value_Type','Data_Value_Alt','Data_Value_Footnote_Symbol','Data_Value_Footnote','Total', 'DataValueTypeID'], axis=1)
q037_df_trim
# Out:
#        YearStart  YearEnd LocationAbbr  LocationDesc  \
# 0           2013     2013           US      National
# 1           2012     2012           WY       Wyoming
# 2           2015     2015           RI  Rhode Island
# 3           2015     2015           GU          Guam
# 4           2012     2012           US      National
# ...          ...      ...          ...           ...
# 18112       2022     2022           WY       Wyoming
# 18113       2022     2022           WY       Wyoming
# 18114       2022     2022           WY       Wyoming
# 18115       2022     2022           WY       Wyoming
# 18116       2022     2022           WY       Wyoming
#
#                                                 Question  Data_Value  \
# 0      Percent of adults aged 18 years and older who ...        32.7
# 1      Percent of adults aged 18 years and older who ...        48.5
# 2      Percent of adults aged 18 years and older who ...        40.2
# 3      Percent of adults aged 18 years and older who ...         NaN
# 4      Percent of adults aged 18 years and older who ...        35.1
# ...                                                  ...         ...
# 18112  Percent of adults aged 18 years and older who ...        41.5
# 18113  Percent of adults aged 18 years and older who ...        38.0
# 18114  Percent of adults aged 18 years and older who ...        37.3
# 18115  Percent of adults aged 18 years and older who ...        24.5
# 18116  Percent of adults aged 18 years and older who ...        35.3
#
#        Low_Confidence_Limit  High_Confidence_Limit   Sample_Size Age(years)  \
# 0                      31.9                    33.5      60069.0        NaN
# 1                      32.3                    64.9         69.0        NaN
# 2                      33.3                    47.4        354.0        NaN
# 3                       NaN                     NaN          NaN        NaN
# 4                      34.6                    35.7     120032.0        NaN
# ...                     ...                     ...          ...        ...
# 18112                  37.6                    45.6        722.0    55 - 64
# 18113                  35.4                    40.6       1860.0        NaN
# 18114                  32.8                    42.0        663.0        NaN
# 18115                  16.3                    35.3        111.0        NaN
# 18116                  30.2                    40.7        512.0        NaN
#
#        ...                 Race/Ethnicity  \
# 0      ...                            NaN
# 1      ...  American Indian/Alaska Native
# 2      ...                       Hispanic
# 3      ...                          Other
# 4      ...                            NaN
# ...    ...                            ...
# 18112  ...                            NaN
# 18113  ...                            NaN
# 18114  ...                            NaN
# 18115  ...                            NaN
# 18116  ...                            NaN
#
#                                     GeoLocation ClassID TopicID QuestionID  \
# 0                                           NaN     OWS    OWS1       Q037
# 1                (43.235541343, -108.109830353)     OWS    OWS1       Q037
# 2                 (41.708280193, -71.522470314)     OWS    OWS1       Q037
# 3                       (13.444304, 144.793731)     OWS    OWS1       Q037
# 4                                           NaN     OWS    OWS1       Q037
# ...                                         ...     ...     ...        ...
# 18112  (43.23554134300048, -108.10983035299967)     OWS    OWS1       Q037
# 18113  (43.23554134300048, -108.10983035299967)     OWS    OWS1       Q037
# 18114  (43.23554134300048, -108.10983035299967)     OWS    OWS1       Q037
# 18115  (43.23554134300048, -108.10983035299967)     OWS    OWS1       Q037
# 18116  (43.23554134300048, -108.10983035299967)     OWS    OWS1       Q037
#
#       LocationID StratificationCategory1                   Stratification1  \
# 0             59                  Income                 Data not reported
# 1             56          Race/Ethnicity     American Indian/Alaska Native
# 2             44          Race/Ethnicity                          Hispanic
# 3             66          Race/Ethnicity                             Other
# 4             59               Education  Some college or technical school
# ...          ...                     ...                               ...
# 18112         56             Age (years)                           55 - 64
# 18113         56                  Gender                              Male
# 18114         56                  Income                 $50,000 - $74,999
# 18115         56                  Income                 Less than $15,000
# 18116         56                  Income                 $35,000 - $49,999
#
#        StratificationCategoryId1 StratificationID1
# 0                            INC             INCNR
# 1                           RACE           RACENAA
# 2                           RACE           RACEHIS
# 3                           RACE           RACEOTH
# 4                            EDU          EDUCOTEC
# ...                          ...               ...
# 18112                      AGEYR         AGEYR5564
# 18113                        GEN              MALE
# 18114                        INC           INC5075
# 18115                        INC         INCLESS15
# 18116                        INC           INC3550
#
# [18117 rows x 23 columns]

# %%
# Remove the names of the territories
q037_df_trim_filtered = q037_df_trim[~q037_df_trim['LocationDesc'].str.contains('Guam|Virgin Islands|Puerto Rico')]

#remove NA Data value
q037_df_trim_cleaned = q037_df_trim_filtered.dropna(subset=['Data_Value'])
q037_df_trim_cleaned
# Out:
#        YearStart  YearEnd LocationAbbr  LocationDesc  \
# 0           2013     2013           US      National
# 1           2012     2012           WY       Wyoming
# 2           2015     2015           RI  Rhode Island
# 4           2012     2012           US      National
# 7           2011     2011           US      National
# ...          ...      ...          ...           ...
# 18112       2022     2022           WY       Wyoming
# 18113       2022     2022           WY       Wyoming
# 18114       2022     2022           WY       Wyoming
# 18115       2022     2022           WY       Wyoming
# 18116       2022     2022           WY       Wyoming
#
#                                                 Question  Data_Value  \
# 0      Percent of adults aged 18 years and older who ...        32.7
# 1      Percent of adults aged 18 years and older who ...        48.5
# 2      Percent of adults aged 18 years and older who ...        40.2
# 4      Percent of adults aged 18 years and older who ...        35.1
# 7      Percent of adults aged 18 years and older who ...        31.6
# ...                                                  ...         ...
# 18112  Percent of adults aged 18 years and older who ...        41.5
# 18113  Percent of adults aged 18 years and older who ...        38.0
# 18114  Percent of adults aged 18 years and older who ...        37.3
# 18115  Percent of adults aged 18 years and older who ...        24.5
# 18116  Percent of adults aged 18 years and older who ...        35.3
#
#        Low_Confidence_Limit  High_Confidence_Limit   Sample_Size Age(years)  \
# 0                      31.9                    33.5      60069.0        NaN
# 1                      32.3                    64.9         69.0        NaN
# 2                      33.3                    47.4        354.0        NaN
# 4                      34.6                    35.7     120032.0        NaN
# 7                      30.7                    32.6      49576.0        NaN
# ...                     ...                     ...          ...        ...
# 18112                  37.6                    45.6        722.0    55 - 64
# 18113                  35.4                    40.6       1860.0        NaN
# 18114                  32.8                    42.0        663.0        NaN
# 18115                  16.3                    35.3        111.0        NaN
# 18116                  30.2                    40.7        512.0        NaN
#
#        ...                 Race/Ethnicity  \
# 0      ...                            NaN
# 1      ...  American Indian/Alaska Native
# 2      ...                       Hispanic
# 4      ...                            NaN
# 7      ...                            NaN
# ...    ...                            ...
# 18112  ...                            NaN
# 18113  ...                            NaN
# 18114  ...                            NaN
# 18115  ...                            NaN
# 18116  ...                            NaN
#
#                                     GeoLocation ClassID TopicID QuestionID  \
# 0                                           NaN     OWS    OWS1       Q037
# 1                (43.235541343, -108.109830353)     OWS    OWS1       Q037
# 2                 (41.708280193, -71.522470314)     OWS    OWS1       Q037
# 4                                           NaN     OWS    OWS1       Q037
# 7                                           NaN     OWS    OWS1       Q037
# ...                                         ...     ...     ...        ...
# 18112  (43.23554134300048, -108.10983035299967)     OWS    OWS1       Q037
# 18113  (43.23554134300048, -108.10983035299967)     OWS    OWS1       Q037
# 18114  (43.23554134300048, -108.10983035299967)     OWS    OWS1       Q037
# 18115  (43.23554134300048, -108.10983035299967)     OWS    OWS1       Q037
# 18116  (43.23554134300048, -108.10983035299967)     OWS    OWS1       Q037
#
#       LocationID StratificationCategory1                   Stratification1  \
# 0             59                  Income                 Data not reported
# 1             56          Race/Ethnicity     American Indian/Alaska Native
# 2             44          Race/Ethnicity                          Hispanic
# 4             59               Education  Some college or technical school
# 7             59                  Income                 Less than $15,000
# ...          ...                     ...                               ...
# 18112         56             Age (years)                           55 - 64
# 18113         56                  Gender                              Male
# 18114         56                  Income                 $50,000 - $74,999
# 18115         56                  Income                 Less than $15,000
# 18116         56                  Income                 $35,000 - $49,999
#
#        StratificationCategoryId1 StratificationID1
# 0                            INC             INCNR
# 1                           RACE           RACENAA
# 2                           RACE           RACEHIS
# 4                            EDU          EDUCOTEC
# 7                            INC         INCLESS15
# ...                          ...               ...
# 18112                      AGEYR         AGEYR5564
# 18113                        GEN              MALE
# 18114                        INC           INC5075
# 18115                        INC         INCLESS15
# 18116                        INC           INC3550
#
# [15836 rows x 23 columns]

# %%
#filter only National data
q037_natl_df = q037_df_trim_cleaned[q037_df_trim_cleaned['LocationDesc'].str.contains('National')].sort_values(by=['YearStart', 'Stratification1'])
q037_natl_df
# Out:
#        YearStart  YearEnd LocationAbbr LocationDesc  \
# 996         2011     2011           US     National
# 20          2011     2011           US     National
# 4108        2011     2011           US     National
# 2633        2011     2011           US     National
# 3686        2011     2011           US     National
# ...          ...      ...          ...          ...
# 1543        2022     2022           US     National
# 2377        2022     2022           US     National
# 17884       2022     2022           US     National
# 17891       2022     2022           US     National
# 2351        2022     2022           US     National
#
#                                                 Question  Data_Value  \
# 996    Percent of adults aged 18 years and older who ...        34.5
# 20     Percent of adults aged 18 years and older who ...        35.5
# 4108   Percent of adults aged 18 years and older who ...        37.1
# 2633   Percent of adults aged 18 years and older who ...        37.5
# 3686   Percent of adults aged 18 years and older who ...        38.3
# ...                                                  ...         ...
# 1543   Percent of adults aged 18 years and older who ...        38.9
# 2377   Percent of adults aged 18 years and older who ...        31.6
# 17884  Percent of adults aged 18 years and older who ...        34.5
# 17891  Percent of adults aged 18 years and older who ...        33.6
# 2351   Percent of adults aged 18 years and older who ...        34.1
#
#        Low_Confidence_Limit  High_Confidence_Limit   Sample_Size Age(years)  \
# 996                    33.8                    35.2      74022.0        NaN
# 20                     34.6                    36.4      48923.0        NaN
# 4108                   36.3                    37.9      61329.0        NaN
# 2633                   36.8                    38.3      64664.0        NaN
# 3686                   37.8                    38.9     110079.0        NaN
# ...                     ...                     ...          ...        ...
# 1543                   38.5                    39.4     189865.0        NaN
# 2377                   30.6                    32.6      29914.0        NaN
# 17884                  34.2                    34.8     289595.0        NaN
# 17891                  33.0                    34.2     105991.0        NaN
# 2351                   33.8                    34.4     387549.0        NaN
#
#        ...      Race/Ethnicity GeoLocation ClassID TopicID QuestionID  \
# 996    ...                 NaN         NaN     OWS    OWS1       Q037
# 20     ...                 NaN         NaN     OWS    OWS1       Q037
# 4108   ...                 NaN         NaN     OWS    OWS1       Q037
# 2633   ...                 NaN         NaN     OWS    OWS1       Q037
# 3686   ...                 NaN         NaN     OWS    OWS1       Q037
# ...    ...                 ...         ...     ...     ...        ...
# 1543   ...                 NaN         NaN     OWS    OWS1       Q037
# 2377   ...  Non-Hispanic Black         NaN     OWS    OWS1       Q037
# 17884  ...  Non-Hispanic White         NaN     OWS    OWS1       Q037
# 17891  ...                 NaN         NaN     OWS    OWS1       Q037
# 2351   ...                 NaN         NaN     OWS    OWS1       Q037
#
#       LocationID StratificationCategory1                   Stratification1  \
# 996           59                  Income                 $15,000 - $24,999
# 20            59                  Income                 $25,000 - $34,999
# 4108          59                  Income                 $35,000 - $49,999
# 2633          59                  Income                 $50,000 - $74,999
# 3686          59                  Income                $75,000 or greater
# ...          ...                     ...                               ...
# 1543          59                  Gender                              Male
# 2377          59          Race/Ethnicity                Non-Hispanic Black
# 17884         59          Race/Ethnicity                Non-Hispanic White
# 17891         59               Education  Some college or technical school
# 2351          59                   Total                             Total
#
#        StratificationCategoryId1 StratificationID1
# 996                          INC           INC1525
# 20                           INC           INC2535
# 4108                         INC           INC3550
# 2633                         INC           INC5075
# 3686                         INC         INC75PLUS
# ...                          ...               ...
# 1543                         GEN              MALE
# 2377                        RACE           RACEBLK
# 17884                       RACE           RACEWHT
# 17891                        EDU          EDUCOTEC
# 2351                         OVR           OVERALL
#
# [335 rows x 23 columns]

# %%
q037_df_sorted = q037_df_trim_cleaned.sort_values(by=['YearStart', 'StratificationCategory1', 'Stratification1', 'LocationDesc'])
q037_df_sorted
# Out:
#        YearStart  YearEnd LocationAbbr   LocationDesc  \
# 10273       2011     2011           AL        Alabama
# 7950        2011     2011           AK         Alaska
# 13664       2011     2011           AZ        Arizona
# 5365        2011     2011           AR       Arkansas
# 10633       2011     2011           CA     California
# ...          ...      ...          ...            ...
# 17928       2022     2022           VA       Virginia
# 18006       2022     2022           WA     Washington
# 18083       2022     2022           WV  West Virginia
# 18046       2022     2022           WI      Wisconsin
# 18099       2022     2022           WY        Wyoming
#
#                                                 Question  Data_Value  \
# 10273  Percent of adults aged 18 years and older who ...        27.1
# 7950   Percent of adults aged 18 years and older who ...        32.0
# 13664  Percent of adults aged 18 years and older who ...        27.7
# 5365   Percent of adults aged 18 years and older who ...        27.3
# 10633  Percent of adults aged 18 years and older who ...        26.8
# ...                                                  ...         ...
# 17928  Percent of adults aged 18 years and older who ...        32.1
# 18006  Percent of adults aged 18 years and older who ...        34.6
# 18083  Percent of adults aged 18 years and older who ...        33.4
# 18046  Percent of adults aged 18 years and older who ...        33.0
# 18099  Percent of adults aged 18 years and older who ...        35.6
#
#        Low_Confidence_Limit  High_Confidence_Limit   Sample_Size Age(years)  \
# 10273                  21.6                    33.3        356.0    18 - 24
# 7950                   24.7                    40.4        212.0    18 - 24
# 13664                  20.7                    36.1        212.0    18 - 24
# 5365                   19.6                    36.7        136.0    18 - 24
# 10633                  23.6                    30.3        902.0    18 - 24
# ...                     ...                     ...          ...        ...
# 17928                  30.8                    33.5       9378.0        NaN
# 18006                  33.7                    35.4      22869.0        NaN
# 18083                  31.7                    35.1       4640.0        NaN
# 18046                  31.7                    34.2      10080.0        NaN
# 18099                  33.7                    37.6       3799.0        NaN
#
#        ... Race/Ethnicity                               GeoLocation ClassID  \
# 10273  ...            NaN             (32.840571122, -86.631860762)     OWS
# 7950   ...            NaN         (64.845079957001, -147.722059036)     OWS
# 13664  ...            NaN             (34.86597028, -111.763811277)     OWS
# 5365   ...            NaN             (34.748650124, -92.274490743)     OWS
# 10633  ...            NaN            (37.638640123, -120.999999538)     OWS
# ...    ...            ...                                       ...     ...
# 17928  ...            NaN   (37.54268067400045, -78.45789046299967)     OWS
# 18006  ...            NaN  (47.52227862900048, -120.47001078999972)     OWS
# 18083  ...            NaN   (38.66551020200046, -80.71264013499967)     OWS
# 18046  ...            NaN   (44.39319117400049, -89.81637074199966)     OWS
# 18099  ...            NaN  (43.23554134300048, -108.10983035299967)     OWS
#
#       TopicID QuestionID LocationID StratificationCategory1 Stratification1  \
# 10273    OWS1       Q037          1             Age (years)         18 - 24
# 7950     OWS1       Q037          2             Age (years)         18 - 24
# 13664    OWS1       Q037          4             Age (years)         18 - 24
# 5365     OWS1       Q037          5             Age (years)         18 - 24
# 10633    OWS1       Q037          6             Age (years)         18 - 24
# ...       ...        ...        ...                     ...             ...
# 17928    OWS1       Q037         51                   Total           Total
# 18006    OWS1       Q037         53                   Total           Total
# 18083    OWS1       Q037         54                   Total           Total
# 18046    OWS1       Q037         55                   Total           Total
# 18099    OWS1       Q037         56                   Total           Total
#
#        StratificationCategoryId1 StratificationID1
# 10273                      AGEYR         AGEYR1824
# 7950                       AGEYR         AGEYR1824
# 13664                      AGEYR         AGEYR1824
# 5365                       AGEYR         AGEYR1824
# 10633                      AGEYR         AGEYR1824
# ...                          ...               ...
# 17928                        OVR           OVERALL
# 18006                        OVR           OVERALL
# 18083                        OVR           OVERALL
# 18046                        OVR           OVERALL
# 18099                        OVR           OVERALL
#
# [15836 rows x 23 columns]
