# %%
# Dependencies
import pandas as pd
from pathlib import Path
import missingno as msno

# %%
# Store filepath in a variable
file = Path("Resources/Nutrition__Physical_Activity__and_Obesity_-_Behavioral_Risk_Factor_Surveillance_System.csv")

# %%
# Read our data file with the Pandas library
raw_df = pd.read_csv(file)
raw_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc  \
# 0       2020     2020           US     National
# 1       2014     2014           GU         Guam
# 2       2013     2013           US     National
# 3       2013     2013           US     National
# 4       2015     2015           US     National
#
#                                    Datasource                    Class  \
# 0  Behavioral Risk Factor Surveillance System        Physical Activity
# 1  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 4  Behavioral Risk Factor Surveillance System        Physical Activity
#
#                           Topic  \
# 0  Physical Activity - Behavior
# 1       Obesity / Weight Status
# 2       Obesity / Weight Status
# 3       Obesity / Weight Status
# 4  Physical Activity - Behavior
#
#                                             Question  Data_Value_Unit  \
# 0  Percent of adults who engage in no leisure-tim...              NaN
# 1  Percent of adults aged 18 years and older who ...              NaN
# 2  Percent of adults aged 18 years and older who ...              NaN
# 3  Percent of adults aged 18 years and older who ...              NaN
# 4  Percent of adults who achieve at least 300 min...              NaN
#
#   Data_Value_Type  ...              GeoLocation  ClassID TopicID QuestionID  \
# 0           Value  ...                      NaN       PA     PA1       Q047
# 1           Value  ...  (13.444304, 144.793731)      OWS    OWS1       Q036
# 2           Value  ...                      NaN      OWS    OWS1       Q036
# 3           Value  ...                      NaN      OWS    OWS1       Q037
# 4           Value  ...                      NaN       PA     PA1       Q045
#
#    DataValueTypeID  LocationID  StratificationCategory1       Stratification1  \
# 0            VALUE          59           Race/Ethnicity              Hispanic
# 1            VALUE          66                Education  High school graduate
# 2            VALUE          59                   Income     $50,000 - $74,999
# 3            VALUE          59                   Income     Data not reported
# 4            VALUE          59                   Income     Less than $15,000
#
#   StratificationCategoryId1 StratificationID1
# 0                      RACE           RACEHIS
# 1                       EDU         EDUHSGRAD
# 2                       INC           INC5075
# 3                       INC             INCNR
# 4                       INC         INCLESS15
#
# [5 rows x 33 columns]

# %%
# %matplotlib inline
msno.matrix(raw_df)
# Out:
# <Axes: >

# %%
raw_df.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'Datasource',
#        'Class', 'Topic', 'Question', 'Data_Value_Unit', 'Data_Value_Type',
#        'Data_Value', 'Data_Value_Alt', 'Data_Value_Footnote_Symbol',
#        'Data_Value_Footnote', 'Low_Confidence_Limit', 'High_Confidence_Limit ',
#        'Sample_Size', 'Total', 'Age(years)', 'Education', 'Gender', 'Income',
#        'Race/Ethnicity', 'GeoLocation', 'ClassID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'LocationID', 'StratificationCategory1',
#        'Stratification1', 'StratificationCategoryId1', 'StratificationID1'],
#       dtype='object')

# %%
# Delete specific columns using drop()
columns_to_drop = [
    'YearEnd', 'Datasource', 'Class', 'Topic', 'Data_Value_Unit',
    'Data_Value_Type', 'Data_Value_Alt', 'Data_Value_Footnote_Symbol',
    'Data_Value_Footnote', 'Low_Confidence_Limit',
    'High_Confidence_Limit ', 'Sample_Size', 'Total', 'Age(years)',
    'Education', 'Gender', 'Income', 'Race/Ethnicity', 'GeoLocation',
    'ClassID', 'TopicID', 'DataValueTypeID', 'LocationID',
    'StratificationCategory1', 'StratificationCategoryId1']
dropped_df = raw_df.drop(columns=columns_to_drop)
dropped_df
# Out:
#        YearStart LocationAbbr LocationDesc  \
# 0           2020           US     National
# 1           2014           GU         Guam
# 2           2013           US     National
# 3           2013           US     National
# 4           2015           US     National
# ...          ...          ...          ...
# 93244       2022           WY      Wyoming
# 93245       2022           WY      Wyoming
# 93246       2022           WY      Wyoming
# 93247       2022           WY      Wyoming
# 93248       2022           WY      Wyoming
#
#                                                 Question  Data_Value  \
# 0      Percent of adults who engage in no leisure-tim...        30.6
# 1      Percent of adults aged 18 years and older who ...        29.3
# 2      Percent of adults aged 18 years and older who ...        28.8
# 3      Percent of adults aged 18 years and older who ...        32.7
# 4      Percent of adults who achieve at least 300 min...        26.6
# ...                                                  ...         ...
# 93244  Percent of adults aged 18 years and older who ...        24.5
# 93245  Percent of adults who engage in no leisure-tim...        36.0
# 93246  Percent of adults aged 18 years and older who ...        35.2
# 93247  Percent of adults aged 18 years and older who ...        35.3
# 93248  Percent of adults aged 18 years and older who ...        41.0
#
#       QuestionID        Stratification1 StratificationID1
# 0           Q047               Hispanic           RACEHIS
# 1           Q036   High school graduate         EDUHSGRAD
# 2           Q036      $50,000 - $74,999           INC5075
# 3           Q037      Data not reported             INCNR
# 4           Q045      Less than $15,000         INCLESS15
# ...          ...                    ...               ...
# 93244       Q037      Less than $15,000         INCLESS15
# 93245       Q047  Less than high school             EDUHS
# 93246       Q036                35 - 44         AGEYR3544
# 93247       Q037      $35,000 - $49,999           INC3550
# 93248       Q036  Less than high school             EDUHS
#
# [93249 rows x 8 columns]

# %%
dropped_df.columns
# Out:
# Index(['YearStart', 'LocationAbbr', 'LocationDesc', 'Question', 'Data_Value',
#        'QuestionID', 'Stratification1', 'StratificationID1'],
#       dtype='object')

# %%
#Reorganize 'QuestionID' to appear before 'Question' column
column_order = ['YearStart', 'LocationAbbr', 'LocationDesc', 'QuestionID', 'Question', 'Data_Value', 'Stratification1', 'StratificationID1']
dropped_df = dropped_df[column_order]
dropped_df
# Out:
#        YearStart LocationAbbr LocationDesc QuestionID  \
# 0           2020           US     National       Q047
# 1           2014           GU         Guam       Q036
# 2           2013           US     National       Q036
# 3           2013           US     National       Q037
# 4           2015           US     National       Q045
# ...          ...          ...          ...        ...
# 93244       2022           WY      Wyoming       Q037
# 93245       2022           WY      Wyoming       Q047
# 93246       2022           WY      Wyoming       Q036
# 93247       2022           WY      Wyoming       Q037
# 93248       2022           WY      Wyoming       Q036
#
#                                                 Question  Data_Value  \
# 0      Percent of adults who engage in no leisure-tim...        30.6
# 1      Percent of adults aged 18 years and older who ...        29.3
# 2      Percent of adults aged 18 years and older who ...        28.8
# 3      Percent of adults aged 18 years and older who ...        32.7
# 4      Percent of adults who achieve at least 300 min...        26.6
# ...                                                  ...         ...
# 93244  Percent of adults aged 18 years and older who ...        24.5
# 93245  Percent of adults who engage in no leisure-tim...        36.0
# 93246  Percent of adults aged 18 years and older who ...        35.2
# 93247  Percent of adults aged 18 years and older who ...        35.3
# 93248  Percent of adults aged 18 years and older who ...        41.0
#
#              Stratification1 StratificationID1
# 0                   Hispanic           RACEHIS
# 1       High school graduate         EDUHSGRAD
# 2          $50,000 - $74,999           INC5075
# 3          Data not reported             INCNR
# 4          Less than $15,000         INCLESS15
# ...                      ...               ...
# 93244      Less than $15,000         INCLESS15
# 93245  Less than high school             EDUHS
# 93246                35 - 44         AGEYR3544
# 93247      $35,000 - $49,999           INC3550
# 93248  Less than high school             EDUHS
#
# [93249 rows x 8 columns]

# %%
trimmed_df = dropped_df[~dropped_df['LocationDesc'].str.contains('Guam|Virgin Islands|Puerto Rico')]
trimmed_df
# Out:
#        YearStart LocationAbbr LocationDesc QuestionID  \
# 0           2020           US     National       Q047
# 2           2013           US     National       Q036
# 3           2013           US     National       Q037
# 4           2015           US     National       Q045
# 6           2012           WY      Wyoming       Q037
# ...          ...          ...          ...        ...
# 93244       2022           WY      Wyoming       Q037
# 93245       2022           WY      Wyoming       Q047
# 93246       2022           WY      Wyoming       Q036
# 93247       2022           WY      Wyoming       Q037
# 93248       2022           WY      Wyoming       Q036
#
#                                                 Question  Data_Value  \
# 0      Percent of adults who engage in no leisure-tim...        30.6
# 2      Percent of adults aged 18 years and older who ...        28.8
# 3      Percent of adults aged 18 years and older who ...        32.7
# 4      Percent of adults who achieve at least 300 min...        26.6
# 6      Percent of adults aged 18 years and older who ...        48.5
# ...                                                  ...         ...
# 93244  Percent of adults aged 18 years and older who ...        24.5
# 93245  Percent of adults who engage in no leisure-tim...        36.0
# 93246  Percent of adults aged 18 years and older who ...        35.2
# 93247  Percent of adults aged 18 years and older who ...        35.3
# 93248  Percent of adults aged 18 years and older who ...        41.0
#
#                      Stratification1 StratificationID1
# 0                           Hispanic           RACEHIS
# 2                  $50,000 - $74,999           INC5075
# 3                  Data not reported             INCNR
# 4                  Less than $15,000         INCLESS15
# 6      American Indian/Alaska Native           RACENAA
# ...                              ...               ...
# 93244              Less than $15,000         INCLESS15
# 93245          Less than high school             EDUHS
# 93246                        35 - 44         AGEYR3544
# 93247              $35,000 - $49,999           INC3550
# 93248          Less than high school             EDUHS
#
# [90029 rows x 8 columns]

# %%
#remove NA Data value
cleaned_df = trimmed_df.dropna(subset=['Data_Value'])

# %%
cleaned_df = cleaned_df.sort_values(by=["YearStart", "QuestionID", "StratificationID1"], ascending=[False, True, True])
cleaned_df
# Out:
#        YearStart LocationAbbr LocationDesc QuestionID  \
# 7208        2022           US     National       Q036
# 8494        2022           VT      Vermont       Q036
# 72417       2022           AL      Alabama       Q036
# 77592       2022           ID        Idaho       Q036
# 88789       2022           AK       Alaska       Q036
# ...          ...          ...          ...        ...
# 71366       2011           AR     Arkansas       Q047
# 71679       2011           TX        Texas       Q047
# 71686       2011           GA      Georgia       Q047
# 73897       2011           IA         Iowa       Q047
# 74815       2011           MI     Michigan       Q047
#
#                                                 Question  Data_Value  \
# 7208   Percent of adults aged 18 years and older who ...        20.5
# 8494   Percent of adults aged 18 years and older who ...        14.7
# 72417  Percent of adults aged 18 years and older who ...        19.8
# 77592  Percent of adults aged 18 years and older who ...        25.0
# 88789  Percent of adults aged 18 years and older who ...        24.5
# ...                                                  ...         ...
# 71366  Percent of adults who engage in no leisure-tim...        31.0
# 71679  Percent of adults who engage in no leisure-tim...        25.0
# 71686  Percent of adults who engage in no leisure-tim...        25.5
# 73897  Percent of adults who engage in no leisure-tim...        25.3
# 74815  Percent of adults who engage in no leisure-tim...        22.2
#
#           Stratification1 StratificationID1
# 7208              18 - 24         AGEYR1824
# 8494              18 - 24         AGEYR1824
# 72417             18 - 24         AGEYR1824
# 77592             18 - 24         AGEYR1824
# 88789             18 - 24         AGEYR1824
# ...                   ...               ...
# 71366  Non-Hispanic White           RACEWHT
# 71679  Non-Hispanic White           RACEWHT
# 71686  Non-Hispanic White           RACEWHT
# 73897  Non-Hispanic White           RACEWHT
# 74815  Non-Hispanic White           RACEWHT
#
# [81649 rows x 8 columns]

# %%
cleaned_df.to_csv("Resources/DNPAO_cleaned.csv", index=False)
