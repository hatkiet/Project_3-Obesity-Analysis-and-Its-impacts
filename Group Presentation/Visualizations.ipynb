# %% [markdown]
# Test notebook

# %%
# Dependencies and Setup
import missingno as msno
import pandas as pd
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
from scipy import stats
from scipy.stats import linregress
import scipy.stats as st
import sys
import json
import requests

# Load the data file, read and display it with Pandas
q036_data = Path("Resources/Extra/Q036.csv")

# Read and store into Pandas DataFrames
q036_df = pd.read_csv(q036_data)
q036_df.head()
# Out:
# /Users/hatkiet/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
#    YearStart  YearEnd LocationAbbr  LocationDesc  \
# 0       2011     2011           AL       Alabama
# 1       2011     2011           US      National
# 2       2011     2011           RI  Rhode Island
# 3       2011     2011           US      National
# 4       2011     2011           US      National
#
#                                    Datasource                    Class  \
# 0  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 4  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
#
#                      Topic                                           Question  \
# 0  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 1  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 2  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 3  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 4  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
#
#    Data_Value_Unit Data_Value_Type  ...                    GeoLocation  \
# 0              NaN           Value  ...  (32.840571122, -86.631860762)
# 1              NaN           Value  ...                            NaN
# 2              NaN           Value  ...  (41.708280193, -71.522470314)
# 3              NaN           Value  ...                            NaN
# 4              NaN           Value  ...                            NaN
#
#    ClassID TopicID QuestionID  DataValueTypeID  LocationID  \
# 0      OWS    OWS1       Q036            VALUE           1
# 1      OWS    OWS1       Q036            VALUE          59
# 2      OWS    OWS1       Q036            VALUE          44
# 3      OWS    OWS1       Q036            VALUE          59
# 4      OWS    OWS1       Q036            VALUE          59
#
#    StratificationCategory1                Stratification1  \
# 0              Age (years)                        25 - 34
# 1           Race/Ethnicity  American Indian/Alaska Native
# 2           Race/Ethnicity                          Other
# 3                   Income              Less than $15,000
# 4              Age (years)                        35 - 44
#
#   StratificationCategoryId1 StratificationID1
# 0                     AGEYR         AGEYR2534
# 1                      RACE           RACENAA
# 2                      RACE           RACEOTH
# 3                       INC         INCLESS15
# 4                     AGEYR         AGEYR3544
#
# [5 rows x 33 columns]

# %%
q036_df.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'Datasource',
#        'Class', 'Topic', 'Question', 'Data_Value_Unit', 'Data_Value_Type',
#        'Data_Value', 'Data_Value_Alt', 'Data_Value_Footnote_Symbol',
#        'Data_Value_Footnote', 'Low_Confidence_Limit', 'High_Confidence_Limit ',
#        'Sample_Size', 'Total', 'Age(years)', 'Education', 'Gender', 'Income',
#        'Race/Ethnicity', 'GeoLocation', 'ClassID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'LocationID', 'StratificationCategory1',
#        'Stratification1', 'StratificationCategoryId1', 'StratificationID1'],
#       dtype='object')

# %%
# Get the overall data for q036 for year of 2022
# Select specific columns by name
# selected_columns = ["YearStart", "LocationAbbr", "Data_Value", "StratificationCategoryId1", "Stratification1"]
# q036_fivecols = q036_df.loc[q036_df["StratificationCategoryId1"] == "OVR", selected_columns]
# q036_fivecols.to_csv("q036_2022_overall.csv", index=False)

# Trim the columns of data to the one we need
q036_fivecols = q036_df.drop(['YearEnd','Datasource',
       'Class', 'Topic', 'Question', 'Data_Value_Unit', 'Data_Value_Type',
       'Data_Value', 'Data_Value_Alt', 'Data_Value_Footnote_Symbol',
       'Data_Value_Footnote', 'Low_Confidence_Limit', 'High_Confidence_Limit ',
       'Sample_Size', 'Total', 'Age(years)', 'Education', 'Gender', 'Income',
       'Race/Ethnicity', 'GeoLocation', 'ClassID', 'TopicID', 'QuestionID',
       'DataValueTypeID', 'LocationID', 'StratificationCategory1',
       'StratificationID1'], axis=1)
q036_fivecols.to_csv("Resources/Extra/q036_fivecols.csv", index=False)

# %%
# Trim the columns of data to the one we need
q036_df_trim = q036_df.drop(['Datasource','Class', 'Topic','Data_Value_Unit', 'Data_Value_Type','Data_Value_Alt','Data_Value_Footnote_Symbol','Data_Value_Footnote','Total', 'DataValueTypeID'], axis=1)
q036_df_trim
# Out:
#        YearStart  YearEnd LocationAbbr  LocationDesc  \
# 0           2011     2011           AL       Alabama
# 1           2011     2011           US      National
# 2           2011     2011           RI  Rhode Island
# 3           2011     2011           US      National
# 4           2011     2011           US      National
# ...          ...      ...          ...           ...
# 18112       2022     2022           WY       Wyoming
# 18113       2022     2022           WY       Wyoming
# 18114       2022     2022           WY       Wyoming
# 18115       2022     2022           WY       Wyoming
# 18116       2022     2022           WY       Wyoming
#
#                                                 Question  Data_Value  \
# 0      Percent of adults aged 18 years and older who ...        35.2
# 1      Percent of adults aged 18 years and older who ...        35.4
# 2      Percent of adults aged 18 years and older who ...        32.1
# 3      Percent of adults aged 18 years and older who ...        32.3
# 4      Percent of adults aged 18 years and older who ...        29.9
# ...                                                  ...         ...
# 18112  Percent of adults aged 18 years and older who ...        35.7
# 18113  Percent of adults aged 18 years and older who ...        32.8
# 18114  Percent of adults aged 18 years and older who ...         NaN
# 18115  Percent of adults aged 18 years and older who ...        35.2
# 18116  Percent of adults aged 18 years and older who ...        41.0
#
#        Low_Confidence_Limit  High_Confidence_Limit   Sample_Size Age(years)  \
# 0                      30.7                    40.0        598.0    25 - 34
# 1                      33.0                    37.9       6649.0        NaN
# 2                      21.6                    44.8        109.0        NaN
# 3                      31.4                    33.2      49598.0        NaN
# 4                      29.2                    30.6      60254.0    35 - 44
# ...                     ...                     ...          ...        ...
# 18112                  32.0                    39.6        959.0        NaN
# 18113                  30.9                    34.7       3356.0        NaN
# 18114                   NaN                     NaN          NaN        NaN
# 18115                  30.6                    40.0        450.0    35 - 44
# 18116                  31.9                    50.8        146.0        NaN
#
#        ...                 Race/Ethnicity  \
# 0      ...                            NaN
# 1      ...  American Indian/Alaska Native
# 2      ...                          Other
# 3      ...                            NaN
# 4      ...                            NaN
# ...    ...                            ...
# 18112  ...                            NaN
# 18113  ...             Non-Hispanic White
# 18114  ...                          Asian
# 18115  ...                            NaN
# 18116  ...                            NaN
#
#                                     GeoLocation ClassID TopicID QuestionID  \
# 0                 (32.840571122, -86.631860762)     OWS    OWS1       Q036
# 1                                           NaN     OWS    OWS1       Q036
# 2                 (41.708280193, -71.522470314)     OWS    OWS1       Q036
# 3                                           NaN     OWS    OWS1       Q036
# 4                                           NaN     OWS    OWS1       Q036
# ...                                         ...     ...     ...        ...
# 18112  (43.23554134300048, -108.10983035299967)     OWS    OWS1       Q036
# 18113  (43.23554134300048, -108.10983035299967)     OWS    OWS1       Q036
# 18114  (43.23554134300048, -108.10983035299967)     OWS    OWS1       Q036
# 18115  (43.23554134300048, -108.10983035299967)     OWS    OWS1       Q036
# 18116  (43.23554134300048, -108.10983035299967)     OWS    OWS1       Q036
#
#       LocationID StratificationCategory1                Stratification1  \
# 0              1             Age (years)                        25 - 34
# 1             59          Race/Ethnicity  American Indian/Alaska Native
# 2             44          Race/Ethnicity                          Other
# 3             59                  Income              Less than $15,000
# 4             59             Age (years)                        35 - 44
# ...          ...                     ...                            ...
# 18112         56               Education           High school graduate
# 18113         56          Race/Ethnicity             Non-Hispanic White
# 18114         56          Race/Ethnicity                          Asian
# 18115         56             Age (years)                        35 - 44
# 18116         56               Education          Less than high school
#
#        StratificationCategoryId1 StratificationID1
# 0                          AGEYR         AGEYR2534
# 1                           RACE           RACENAA
# 2                           RACE           RACEOTH
# 3                            INC         INCLESS15
# 4                          AGEYR         AGEYR3544
# ...                          ...               ...
# 18112                        EDU         EDUHSGRAD
# 18113                       RACE           RACEWHT
# 18114                       RACE           RACEASN
# 18115                      AGEYR         AGEYR3544
# 18116                        EDU             EDUHS
#
# [18117 rows x 23 columns]

# %%
# Remove the names of the territories
q036_df_trim_filtered = q036_df_trim[~q036_df_trim['LocationDesc'].str.contains('Guam|Virgin Islands|Puerto Rico')]

#remove NA Data value
q036_df_trim_cleaned = q036_df_trim_filtered.dropna(subset=['Data_Value'])
q036_df_trim_cleaned
# Out:
#        YearStart  YearEnd LocationAbbr  LocationDesc  \
# 0           2011     2011           AL       Alabama
# 1           2011     2011           US      National
# 2           2011     2011           RI  Rhode Island
# 3           2011     2011           US      National
# 4           2011     2011           US      National
# ...          ...      ...          ...           ...
# 18111       2022     2022           WY       Wyoming
# 18112       2022     2022           WY       Wyoming
# 18113       2022     2022           WY       Wyoming
# 18115       2022     2022           WY       Wyoming
# 18116       2022     2022           WY       Wyoming
#
#                                                 Question  Data_Value  \
# 0      Percent of adults aged 18 years and older who ...        35.2
# 1      Percent of adults aged 18 years and older who ...        35.4
# 2      Percent of adults aged 18 years and older who ...        32.1
# 3      Percent of adults aged 18 years and older who ...        32.3
# 4      Percent of adults aged 18 years and older who ...        29.9
# ...                                                  ...         ...
# 18111  Percent of adults aged 18 years and older who ...        39.0
# 18112  Percent of adults aged 18 years and older who ...        35.7
# 18113  Percent of adults aged 18 years and older who ...        32.8
# 18115  Percent of adults aged 18 years and older who ...        35.2
# 18116  Percent of adults aged 18 years and older who ...        41.0
#
#        Low_Confidence_Limit  High_Confidence_Limit   Sample_Size Age(years)  \
# 0                      30.7                    40.0        598.0    25 - 34
# 1                      33.0                    37.9       6649.0        NaN
# 2                      21.6                    44.8        109.0        NaN
# 3                      31.4                    33.2      49598.0        NaN
# 4                      29.2                    30.6      60254.0    35 - 44
# ...                     ...                     ...          ...        ...
# 18111                  33.1                    45.3        305.0    25 - 34
# 18112                  32.0                    39.6        959.0        NaN
# 18113                  30.9                    34.7       3356.0        NaN
# 18115                  30.6                    40.0        450.0    35 - 44
# 18116                  31.9                    50.8        146.0        NaN
#
#        ...                 Race/Ethnicity  \
# 0      ...                            NaN
# 1      ...  American Indian/Alaska Native
# 2      ...                          Other
# 3      ...                            NaN
# 4      ...                            NaN
# ...    ...                            ...
# 18111  ...                            NaN
# 18112  ...                            NaN
# 18113  ...             Non-Hispanic White
# 18115  ...                            NaN
# 18116  ...                            NaN
#
#                                     GeoLocation ClassID TopicID QuestionID  \
# 0                 (32.840571122, -86.631860762)     OWS    OWS1       Q036
# 1                                           NaN     OWS    OWS1       Q036
# 2                 (41.708280193, -71.522470314)     OWS    OWS1       Q036
# 3                                           NaN     OWS    OWS1       Q036
# 4                                           NaN     OWS    OWS1       Q036
# ...                                         ...     ...     ...        ...
# 18111  (43.23554134300048, -108.10983035299967)     OWS    OWS1       Q036
# 18112  (43.23554134300048, -108.10983035299967)     OWS    OWS1       Q036
# 18113  (43.23554134300048, -108.10983035299967)     OWS    OWS1       Q036
# 18115  (43.23554134300048, -108.10983035299967)     OWS    OWS1       Q036
# 18116  (43.23554134300048, -108.10983035299967)     OWS    OWS1       Q036
#
#       LocationID StratificationCategory1                Stratification1  \
# 0              1             Age (years)                        25 - 34
# 1             59          Race/Ethnicity  American Indian/Alaska Native
# 2             44          Race/Ethnicity                          Other
# 3             59                  Income              Less than $15,000
# 4             59             Age (years)                        35 - 44
# ...          ...                     ...                            ...
# 18111         56             Age (years)                        25 - 34
# 18112         56               Education           High school graduate
# 18113         56          Race/Ethnicity             Non-Hispanic White
# 18115         56             Age (years)                        35 - 44
# 18116         56               Education          Less than high school
#
#        StratificationCategoryId1 StratificationID1
# 0                          AGEYR         AGEYR2534
# 1                           RACE           RACENAA
# 2                           RACE           RACEOTH
# 3                            INC         INCLESS15
# 4                          AGEYR         AGEYR3544
# ...                          ...               ...
# 18111                      AGEYR         AGEYR2534
# 18112                        EDU         EDUHSGRAD
# 18113                       RACE           RACEWHT
# 18115                      AGEYR         AGEYR3544
# 18116                        EDU             EDUHS
#
# [15836 rows x 23 columns]

# %%
#filter only National data
q036_natl_df = q036_df_trim_cleaned[q036_df_trim_cleaned['LocationDesc'].str.contains('National')].sort_values(by=['YearStart', 'Stratification1'])
q036_natl_df
# Out:
#        YearStart  YearEnd LocationAbbr LocationDesc  \
# 27          2011     2011           US     National
# 42          2011     2011           US     National
# 14          2011     2011           US     National
# 18          2011     2011           US     National
# 9           2011     2011           US     National
# ...          ...      ...          ...          ...
# 17808       2022     2022           US     National
# 17906       2022     2022           US     National
# 17904       2022     2022           US     National
# 17907       2022     2022           US     National
# 17902       2022     2022           US     National
#
#                                                 Question  Data_Value  \
# 27     Percent of adults aged 18 years and older who ...        31.3
# 42     Percent of adults aged 18 years and older who ...        29.5
# 14     Percent of adults aged 18 years and older who ...        28.7
# 18     Percent of adults aged 18 years and older who ...        28.4
# 9      Percent of adults aged 18 years and older who ...        22.8
# ...                                                  ...         ...
# 17808  Percent of adults aged 18 years and older who ...        32.6
# 17906  Percent of adults aged 18 years and older who ...        43.0
# 17904  Percent of adults aged 18 years and older who ...        32.5
# 17907  Percent of adults aged 18 years and older who ...        35.9
# 17902  Percent of adults aged 18 years and older who ...        33.3
#
#        Low_Confidence_Limit  High_Confidence_Limit   Sample_Size Age(years)  \
# 27                     30.6                    32.0      74049.0        NaN
# 42                     28.7                    30.4      48943.0        NaN
# 14                     27.9                    29.4      61354.0        NaN
# 18                     27.7                    29.1      64688.0        NaN
# 9                      22.3                    23.3     110120.0        NaN
# ...                     ...                     ...          ...        ...
# 17808                  32.1                    33.0     189865.0        NaN
# 17906                  42.0                    44.1      29914.0        NaN
# 17904                  32.1                    32.8     289595.0        NaN
# 17907                  35.3                    36.5     105991.0        NaN
# 17902                  33.0                    33.6     387549.0        NaN
#
#        ...      Race/Ethnicity GeoLocation ClassID TopicID QuestionID  \
# 27     ...                 NaN         NaN     OWS    OWS1       Q036
# 42     ...                 NaN         NaN     OWS    OWS1       Q036
# 14     ...                 NaN         NaN     OWS    OWS1       Q036
# 18     ...                 NaN         NaN     OWS    OWS1       Q036
# 9      ...                 NaN         NaN     OWS    OWS1       Q036
# ...    ...                 ...         ...     ...     ...        ...
# 17808  ...                 NaN         NaN     OWS    OWS1       Q036
# 17906  ...  Non-Hispanic Black         NaN     OWS    OWS1       Q036
# 17904  ...  Non-Hispanic White         NaN     OWS    OWS1       Q036
# 17907  ...                 NaN         NaN     OWS    OWS1       Q036
# 17902  ...                 NaN         NaN     OWS    OWS1       Q036
#
#       LocationID StratificationCategory1                   Stratification1  \
# 27            59                  Income                 $15,000 - $24,999
# 42            59                  Income                 $25,000 - $34,999
# 14            59                  Income                 $35,000 - $49,999
# 18            59                  Income                 $50,000 - $74,999
# 9             59                  Income                $75,000 or greater
# ...          ...                     ...                               ...
# 17808         59                  Gender                              Male
# 17906         59          Race/Ethnicity                Non-Hispanic Black
# 17904         59          Race/Ethnicity                Non-Hispanic White
# 17907         59               Education  Some college or technical school
# 17902         59                   Total                             Total
#
#        StratificationCategoryId1 StratificationID1
# 27                           INC           INC1525
# 42                           INC           INC2535
# 14                           INC           INC3550
# 18                           INC           INC5075
# 9                            INC         INC75PLUS
# ...                          ...               ...
# 17808                        GEN              MALE
# 17906                       RACE           RACEBLK
# 17904                       RACE           RACEWHT
# 17907                        EDU          EDUCOTEC
# 17902                        OVR           OVERALL
#
# [335 rows x 23 columns]

# %%
q036_df_sorted = q036_df_trim_cleaned.sort_values(by=['YearStart', 'StratificationCategory1', 'Stratification1', 'LocationDesc'])
q036_df_sorted
# Out:
#        YearStart  YearEnd LocationAbbr   LocationDesc  \
# 1410        2011     2011           AL        Alabama
# 1313        2011     2011           AK         Alaska
# 53          2011     2011           AZ        Arizona
# 775         2011     2011           AR       Arkansas
# 1034        2011     2011           CA     California
# ...          ...      ...          ...            ...
# 16589       2022     2022           VA       Virginia
# 18032       2022     2022           WA     Washington
# 18069       2022     2022           WV  West Virginia
# 18039       2022     2022           WI      Wisconsin
# 18098       2022     2022           WY        Wyoming
#
#                                                 Question  Data_Value  \
# 1410   Percent of adults aged 18 years and older who ...        16.3
# 1313   Percent of adults aged 18 years and older who ...        19.8
# 53     Percent of adults aged 18 years and older who ...        18.7
# 775    Percent of adults aged 18 years and older who ...        23.0
# 1034   Percent of adults aged 18 years and older who ...        14.5
# ...                                                  ...         ...
# 16589  Percent of adults aged 18 years and older who ...        35.2
# 18032  Percent of adults aged 18 years and older who ...        31.7
# 18069  Percent of adults aged 18 years and older who ...        41.0
# 18039  Percent of adults aged 18 years and older who ...        37.7
# 18098  Percent of adults aged 18 years and older who ...        34.3
#
#        Low_Confidence_Limit  High_Confidence_Limit   Sample_Size Age(years)  \
# 1410                   12.6                    20.9        356.0    18 - 24
# 1313                   13.4                    28.4        212.0    18 - 24
# 53                     12.7                    26.7        240.0    18 - 24
# 775                    16.1                    31.9        136.0    18 - 24
# 1034                   12.0                    17.4        902.0    18 - 24
# ...                     ...                     ...          ...        ...
# 16589                  33.8                    36.6       9378.0        NaN
# 18032                  30.9                    32.5      22869.0        NaN
# 18069                  39.3                    42.8       4640.0        NaN
# 18039                  36.4                    39.0      10080.0        NaN
# 18098                  32.3                    36.2       3799.0        NaN
#
#        ... Race/Ethnicity                               GeoLocation ClassID  \
# 1410   ...            NaN             (32.840571122, -86.631860762)     OWS
# 1313   ...            NaN         (64.845079957001, -147.722059036)     OWS
# 53     ...            NaN             (34.86597028, -111.763811277)     OWS
# 775    ...            NaN             (34.748650124, -92.274490743)     OWS
# 1034   ...            NaN            (37.638640123, -120.999999538)     OWS
# ...    ...            ...                                       ...     ...
# 16589  ...            NaN   (37.54268067400045, -78.45789046299967)     OWS
# 18032  ...            NaN  (47.52227862900048, -120.47001078999972)     OWS
# 18069  ...            NaN   (38.66551020200046, -80.71264013499967)     OWS
# 18039  ...            NaN   (44.39319117400049, -89.81637074199966)     OWS
# 18098  ...            NaN  (43.23554134300048, -108.10983035299967)     OWS
#
#       TopicID QuestionID LocationID StratificationCategory1 Stratification1  \
# 1410     OWS1       Q036          1             Age (years)         18 - 24
# 1313     OWS1       Q036          2             Age (years)         18 - 24
# 53       OWS1       Q036          4             Age (years)         18 - 24
# 775      OWS1       Q036          5             Age (years)         18 - 24
# 1034     OWS1       Q036          6             Age (years)         18 - 24
# ...       ...        ...        ...                     ...             ...
# 16589    OWS1       Q036         51                   Total           Total
# 18032    OWS1       Q036         53                   Total           Total
# 18069    OWS1       Q036         54                   Total           Total
# 18039    OWS1       Q036         55                   Total           Total
# 18098    OWS1       Q036         56                   Total           Total
#
#        StratificationCategoryId1 StratificationID1
# 1410                       AGEYR         AGEYR1824
# 1313                       AGEYR         AGEYR1824
# 53                         AGEYR         AGEYR1824
# 775                        AGEYR         AGEYR1824
# 1034                       AGEYR         AGEYR1824
# ...                          ...               ...
# 16589                        OVR           OVERALL
# 18032                        OVR           OVERALL
# 18069                        OVR           OVERALL
# 18039                        OVR           OVERALL
# 18098                        OVR           OVERALL
#
# [15836 rows x 23 columns]

# %% [markdown]
# # Visualizations focus on a specific year, i.e., 2022

# %%
q036_2022 = q036_df_sorted.loc[q036_df_sorted["YearStart"] == 2022]
q036_2022
# Out:
#        YearStart  YearEnd LocationAbbr   LocationDesc  \
# 16607       2022     2022           AL        Alabama
# 16654       2022     2022           AK         Alaska
# 16737       2022     2022           AZ        Arizona
# 16710       2022     2022           AR       Arkansas
# 16770       2022     2022           CA     California
# ...          ...      ...          ...            ...
# 16589       2022     2022           VA       Virginia
# 18032       2022     2022           WA     Washington
# 18069       2022     2022           WV  West Virginia
# 18039       2022     2022           WI      Wisconsin
# 18098       2022     2022           WY        Wyoming
#
#                                                 Question  Data_Value  \
# 16607  Percent of adults aged 18 years and older who ...        19.8
# 16654  Percent of adults aged 18 years and older who ...        24.5
# 16737  Percent of adults aged 18 years and older who ...        23.3
# 16710  Percent of adults aged 18 years and older who ...        27.6
# 16770  Percent of adults aged 18 years and older who ...        13.8
# ...                                                  ...         ...
# 16589  Percent of adults aged 18 years and older who ...        35.2
# 18032  Percent of adults aged 18 years and older who ...        31.7
# 18069  Percent of adults aged 18 years and older who ...        41.0
# 18039  Percent of adults aged 18 years and older who ...        37.7
# 18098  Percent of adults aged 18 years and older who ...        34.3
#
#        Low_Confidence_Limit  High_Confidence_Limit   Sample_Size Age(years)  \
# 16607                  13.9                    27.4        182.0    18 - 24
# 16654                  19.4                    30.6        324.0    18 - 24
# 16737                  18.5                    29.0        481.0    18 - 24
# 16710                  21.4                    34.8        219.0    18 - 24
# 16770                  11.3                    16.9        869.0    18 - 24
# ...                     ...                     ...          ...        ...
# 16589                  33.8                    36.6       9378.0        NaN
# 18032                  30.9                    32.5      22869.0        NaN
# 18069                  39.3                    42.8       4640.0        NaN
# 18039                  36.4                    39.0      10080.0        NaN
# 18098                  32.3                    36.2       3799.0        NaN
#
#        ... Race/Ethnicity                                GeoLocation ClassID  \
# 16607  ...            NaN    (32.84057112200048, -86.63186076199969)     OWS
# 16654  ...            NaN   (64.84507995700051, -147.72205903599973)     OWS
# 16737  ...            NaN  (34.865970280000454, -111.76381127699972)     OWS
# 16710  ...            NaN    (34.74865012400045, -92.27449074299966)     OWS
# 16770  ...            NaN   (37.63864012300047, -120.99999953799971)     OWS
# ...    ...            ...                                        ...     ...
# 16589  ...            NaN    (37.54268067400045, -78.45789046299967)     OWS
# 18032  ...            NaN   (47.52227862900048, -120.47001078999972)     OWS
# 18069  ...            NaN    (38.66551020200046, -80.71264013499967)     OWS
# 18039  ...            NaN    (44.39319117400049, -89.81637074199966)     OWS
# 18098  ...            NaN   (43.23554134300048, -108.10983035299967)     OWS
#
#       TopicID QuestionID LocationID StratificationCategory1 Stratification1  \
# 16607    OWS1       Q036          1             Age (years)         18 - 24
# 16654    OWS1       Q036          2             Age (years)         18 - 24
# 16737    OWS1       Q036          4             Age (years)         18 - 24
# 16710    OWS1       Q036          5             Age (years)         18 - 24
# 16770    OWS1       Q036          6             Age (years)         18 - 24
# ...       ...        ...        ...                     ...             ...
# 16589    OWS1       Q036         51                   Total           Total
# 18032    OWS1       Q036         53                   Total           Total
# 18069    OWS1       Q036         54                   Total           Total
# 18039    OWS1       Q036         55                   Total           Total
# 18098    OWS1       Q036         56                   Total           Total
#
#        StratificationCategoryId1 StratificationID1
# 16607                      AGEYR         AGEYR1824
# 16654                      AGEYR         AGEYR1824
# 16737                      AGEYR         AGEYR1824
# 16710                      AGEYR         AGEYR1824
# 16770                      AGEYR         AGEYR1824
# ...                          ...               ...
# 16589                        OVR           OVERALL
# 18032                        OVR           OVERALL
# 18069                        OVR           OVERALL
# 18039                        OVR           OVERALL
# 18098                        OVR           OVERALL
#
# [1315 rows x 23 columns]

# %%
# Output the
q036_2022_states_age = q036_2022.loc[q036_2022["StratificationCategoryId1"] == "AGEYR"]
q036_2022_states_age.to_csv("Resources/Extra/q036_2022_states_age.csv", index=False)

# %%
#3d Plot by HLee
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator

age = np.unique(np.array(q036_2022_states_age['Stratification1']))
state = np.unique(np.array(q036_2022_states_age['LocationAbbr']))

XUniques, Xt = np.unique(q036_2022_states_age['LocationAbbr'], return_inverse=True)
YUniques, Yt = np.unique(q036_2022_states_age['Stratification1'], return_inverse=True)
Zt = q036_2022_states_age['Data_Value']

#figsize large due to state abbr, need another solution for prettiness, works for now, contrained isnt being applied
fig=plt.figure(figsize=(20,20),layout='constrained')
ax= fig.add_subplot(projection='3d')
#color function needs fix
ax.scatter(Xt, Yt, Zt, c=np.arange((len(state)*6)), cmap=cm.coolwarm,linewidth=0, antialiased=False)

ax.set_xticks(range(len(state)), labels=state, ha='right',rotation=45)
ax.set_yticks(range(len(age)), labels=age, ha='left')
plt.show()
# Out:
# /Users/hatkiet/anaconda3/envs/dev/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: constrained_layout not applied because axes sizes collapsed to zero.  Try making figure larger or axes decorations smaller.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 10))

# Create a scatter plot
plt.scatter(q036_2022_states_age["Stratification1"], q036_2022_states_age["LocationAbbr"], c=q036_2022_states_age["Data_Value"], cmap='viridis')

# Set labels and title
plt.xlabel('Age Ranges')
plt.ylabel('States')
plt.title('Scatter Plot of Data_Value against Stratification1 and LocationAbbr')

# Add colorbar
plt.colorbar(label='Data_Value')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Group the DataFrame by 'Stratification1' and 'LocationAbbr' and calculate the median Data_Value for each group
grouped_data = q036_2022_states_age.groupby(['Stratification1', 'LocationAbbr'])['Data_Value'].median().unstack()

# Plot a bar plot for each value in 'Stratification1'
grouped_data.plot(kind='bar', figsize=(12, 6))

# Set labels and title
plt.xlabel('LocationAbbr')
plt.ylabel('Data_Value')
plt.title('Bar Plot of Data_Value vs. LocationAbbr for each Stratification1')

# Show the plot
plt.legend(title='Stratification1', bbox_to_anchor=(1, 1))
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/vf/fx_p1h7d1tz18tzk1bj4b9nw0000gn/T/ipykernel_7892/277741081.py:17: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
# Get unique values of age range
age_ranges = q036_2022_states_age["Stratification1"].unique()

# Set the number of rows and columns for subplots
num_rows = len(age_ranges)
num_cols = 1  # Each age range will have its own subplot

# Create subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(12, 6*num_rows))

# Iterate over unique age range
for i, age in enumerate(age_ranges):
    # Filter the DataFrame for the current age range
    filtered_data = q036_2022_states_age[q036_2022_states_age["Stratification1"] == age]
    # Group by States, calculate the median Data_Value for each group, and sort in ascending order
    grouped_data = filtered_data.groupby('LocationAbbr')['Data_Value'].median().sort_values(ascending=False)

    # Plot a bar plot for the current age range value in the corresponding subplot
    ax = axes[i] if num_rows > 1 else axes
    colors = plt.cm.rainbow(grouped_data.values / max(grouped_data.values))  # Use rainbow colormap
    grouped_data.plot(kind='bar', ax=ax, color=colors)
    ax.set_title(f'Age range: {age}')
    ax.set_xlabel('States')
    ax.set_ylabel('Percent (%)')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Output 
q036_2022_states_income = q036_2022.loc[q036_2022["StratificationCategoryId1"] == "INC"]
q036_2022_states_income.to_csv("Resources/Extra/q036_2022_states_income.csv", index=False)

# %%
# Get unique values of income range
income_ranges = q036_2022_states_income["Stratification1"].unique()

# Set the number of rows and columns for subplots
num_rows = len(income_ranges)
num_cols = 1  # Each income range will have its own subplot

# Create subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(12, 6*num_rows))

# Iterate over unique income range
for i, income in enumerate(income_ranges):
    # Filter the DataFrame for the current income range
    filtered_data = q036_2022_states_income[q036_2022_states_income["Stratification1"] == income]
    # Group by States, calculate the median Data_Value for each group, and sort in ascending order
    grouped_data = filtered_data.groupby('LocationAbbr')['Data_Value'].median().sort_values(ascending=False)

    # Plot a bar plot for the current income range value in the corresponding subplot
    ax = axes[i] if num_rows > 1 else axes
    colors = plt.cm.rainbow(grouped_data.values / max(grouped_data.values))  # Use rainbow colormap
    grouped_data.plot(kind='bar', ax=ax, color=colors)
    ax.set_title(f'income range: {income}')
    ax.set_xlabel('States')
    ax.set_ylabel('Percent (%)')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Output 
q036_2022_states_edu = q036_2022.loc[q036_2022["StratificationCategoryId1"] == "EDU"]
q036_2022_states_edu.to_csv("Resources/Extra/q036_2022_states_edu.csv", index=False)

# %%
# Get unique values of edu range
edu_ranges = q036_2022_states_edu["Stratification1"].unique()

# Set the number of rows and columns for subplots
num_rows = len(edu_ranges)
num_cols = 1  # Each edu range will have its own subplot

# Create subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(12, 6*num_rows))

# Iterate over unique edu range
for i, edu in enumerate(edu_ranges):
    # Filter the DataFrame for the current edu range
    filtered_data = q036_2022_states_edu[q036_2022_states_edu["Stratification1"] == edu]
    # Group by States, calculate the median Data_Value for each group, and sort in ascending order
    grouped_data = filtered_data.groupby('LocationAbbr')['Data_Value'].median().sort_values(ascending=False)

    # Plot a bar plot for the current edu range value in the corresponding subplot
    ax = axes[i] if num_rows > 1 else axes
    grouped_data.plot(kind='bar', ax=ax, color=colors)
    ax.set_title(f'edu range: {edu}')
    ax.set_xlabel('States')
    ax.set_ylabel('Percent (%)')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Output 
q036_2022_states_race = q036_2022.loc[q036_2022["StratificationCategoryId1"] == "RACE"]
q036_2022_states_race.to_csv("Resources/Extra/q036_2022_states_race.csv", index=False)

# %%
# Get unique values of race range
races = q036_2022_states_race["Stratification1"].unique()

# Set the number of rows and columns for subplots
num_rows = len(races)
num_cols = 1  # Each race will have its own subplot

# Create subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(12, 6*num_rows))

# Iterate over unique race range
for i, race in enumerate(races):
    # Filter the DataFrame for the current race 
    filtered_data = q036_2022_states_race[q036_2022_states_race["Stratification1"] == race]
    # Group by States, calculate the median Data_Value for each group, and sort in ascending order
    grouped_data = filtered_data.groupby('LocationAbbr')['Data_Value'].median().sort_values(ascending=False)

    # Plot a bar plot for the current race range value in the corresponding subplot
    ax = axes[i] if num_rows > 1 else axes
    grouped_data.plot(kind='bar', ax=ax, color=colors)
    ax.set_title(f'Race/Ethnicity: {race}')
    ax.set_xlabel('States')
    ax.set_ylabel('Percent (%)')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Output 
q036_2022_states_gen = q036_2022.loc[q036_2022["StratificationCategoryId1"] == "GEN"]
q036_2022_states_gen.to_csv("Resources/Extra/q036_2022_states_gen.csv", index=False)

# %%
# Get unique values of genders
genders = q036_2022_states_gen["Stratification1"].unique()

# Set the number of rows and columns for subplots
num_rows = len(genders)
num_cols = 1  # Each gen will have its own subplot

# Create subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(12, 6*num_rows))

# Iterate over unique gender
for i, gen in enumerate(genders):
    # Filter the DataFrame for the current gen 
    filtered_data = q036_2022_states_gen[q036_2022_states_gen["Stratification1"] == gen]
    # Group by States, calculate the median Data_Value for each group, and sort in ascending order
    grouped_data = filtered_data.groupby('LocationAbbr')['Data_Value'].median().sort_values(ascending=False)

    # Plot a bar plot for the current gen range value in the corresponding subplot
    ax = axes[i] if num_rows > 1 else axes
    grouped_data.plot(kind='bar', ax=ax, color=colors)
    ax.set_title(f'Gender: {gen}')
    ax.set_xlabel('States')
    ax.set_ylabel('Percent (%)')

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# # National level

# %%
q036_natl_2022 = q036_natl_df.loc[q036_natl_df["YearStart"] == 2022].sort_values(by=['StratificationCategoryId1', 'Stratification1'])
q036_natl_2022.to_csv("Resources/Extra/q036_natl_2022.csv", index=False)

# %%
# Get unique values of genders
strats = q036_natl_2022["StratificationCategoryId1"].unique()

# Set the number of rows and columns for subplots
num_rows = len(strats)
num_cols = 1  # Each gen will have its own subplot

# Create subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(12, 6*num_rows))

# Iterate over unique gender
for i, strat in enumerate(strats):
    # Filter the DataFrame for the current gen 
    filtered_data = q036_natl_2022[q036_natl_2022["StratificationCategoryId1"] == strat]
    # Group by States, calculate the median Data_Value for each group, and sort in ascending order
    grouped_data = filtered_data.groupby('Stratification1')['Data_Value'].median().sort_values(ascending=False)

    # Plot a bar plot for the current gen range value in the corresponding subplot
    ax = axes[i] if num_rows > 1 else axes
    grouped_data.plot(kind='bar', ax=ax, color=colors)
    ax.set_title(f'{strat}')
    ax.set_xlabel('')
    ax.set_ylabel('Percent (%)')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Get the overall data for q036 for year of 2022
# Select specific columns by name
selected_columns = ["YearStart", "LocationAbbr", "LocationDesc", "Data_Value"]
q036_2022_overall = q036_2022.loc[q036_2022["StratificationCategoryId1"] == "OVR", selected_columns]
q036_2022_overall.to_csv("Resources/Extra/q036_2022_overall.csv", index=False)
