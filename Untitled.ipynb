# %% [markdown]
# Test notebook

# %%
import missingno as msno

# %%
#!/usr/bin/env python

# make sure to install these packages before running:
# pip install pandas
# pip install sodapy

import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cdc.gov", "api-token")

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cdc.gov,
#                  MyAppToken,
#                  username="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("hn4x-zwk7", limit=100000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)

# %%
results_csv_df = pd.read_csv('Nutrition__Physical_Activity__and_Obesity_-_Behavioral_Risk_Factor_Surveillance_System.csv')
results_csv_df.head(5)
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc  \
# 0       2020     2020           US     National
# 1       2014     2014           GU         Guam
# 2       2013     2013           US     National
# 3       2013     2013           US     National
# 4       2015     2015           US     National
#
#                                    Datasource                    Class  \
# 0  Behavioral Risk Factor Surveillance System        Physical Activity
# 1  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 4  Behavioral Risk Factor Surveillance System        Physical Activity
#
#                           Topic  \
# 0  Physical Activity - Behavior
# 1       Obesity / Weight Status
# 2       Obesity / Weight Status
# 3       Obesity / Weight Status
# 4  Physical Activity - Behavior
#
# ...

# %%
# %matplotlib inline
msno.matrix(results_csv_df)
# Out:
# <Axes: >

# %%
results_csv_cleaned = results_csv_df.drop(columns=['Data_Value_Unit'])
df = results_csv_cleaned.dropna()
df
# Out:
# Empty DataFrame
# Columns: [YearStart, YearEnd, LocationAbbr, LocationDesc, Datasource, Class, Topic, Question, Data_Value_Type, Data_Value, Data_Value_Alt, Data_Value_Footnote_Symbol, Data_Value_Footnote, Low_Confidence_Limit, High_Confidence_Limit , Sample_Size, Total, Age(years), Education, Gender, Income, Race/Ethnicity, GeoLocation, ClassID, TopicID, QuestionID, DataValueTypeID, LocationID, StratificationCategory1, Stratification1, StratificationCategoryId1, StratificationID1]
# Index: []
#
# [0 rows x 32 columns]

# %%
results_df['income']
# %matplotlib inline
msno.matrix(results_df)
# Out:
# <Axes: >
