# %% [markdown]
# Test notebook

# %%
# Dependencies and Setup
import missingno as msno
import pandas as pd
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
from scipy import stats
from scipy.stats import linregress
import scipy.stats as st
import sys
import json
import requests

# Load the data file, read and display it with Pandas
DNPAO_all_data = Path("DNPAO_all.csv")

# Read and store into Pandas DataFrames
DNPAO_all = pd.read_csv(DNPAO_all_data)
DNPAO_all.head()
# Out:
#    YearStart  YearEnd LocationAbbr  LocationDesc  \
# 0       2011     2011           AL       Alabama
# 1       2011     2011           US      National
# 2       2011     2011           RI  Rhode Island
# 3       2011     2011           US      National
# 4       2011     2011           US      National
#
#                                    Datasource                    Class  \
# 0  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3  Behavioral Risk Factor Surveillance System        Physical Activity
# 4  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
#
#                           Topic  \
# 0       Obesity / Weight Status
# 1       Obesity / Weight Status
# 2       Obesity / Weight Status
# 3  Physical Activity - Behavior
# 4       Obesity / Weight Status
#
#                                             Question  Data_Value_Unit  \
# 0  Percent of adults aged 18 years and older who ...              NaN
# 1  Percent of adults aged 18 years and older who ...              NaN
# 2  Percent of adults aged 18 years and older who ...              NaN
# 3  Percent of adults who engage in no leisure-tim...              NaN
# 4  Percent of adults aged 18 years and older who ...              NaN
#
#   Data_Value_Type  ...                    GeoLocation  ClassID TopicID  \
# 0           Value  ...  (32.840571122, -86.631860762)      OWS    OWS1
# 1           Value  ...                            NaN      OWS    OWS1
# 2           Value  ...  (41.708280193, -71.522470314)      OWS    OWS1
# 3           Value  ...                            NaN       PA     PA1
# 4           Value  ...                            NaN      OWS    OWS1
#
#   QuestionID  DataValueTypeID  LocationID  StratificationCategory1  \
# 0       Q036            VALUE           1              Age (years)
# 1       Q036            VALUE          59           Race/Ethnicity
# 2       Q036            VALUE          44           Race/Ethnicity
# 3       Q047            VALUE          59              Age (years)
# 4       Q037            VALUE          59                   Income
#
#                  Stratification1 StratificationCategoryId1 StratificationID1
# 0                        25 - 34                     AGEYR         AGEYR2534
# 1  American Indian/Alaska Native                      RACE           RACENAA
# 2                          Other                      RACE           RACEOTH
# 3                        18 - 24                     AGEYR         AGEYR1824
# 4              Less than $15,000                       INC         INCLESS15
#
# [5 rows x 33 columns]

# %%
DNPAO_all.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'Datasource',
#        'Class', 'Topic', 'Question', 'Data_Value_Unit', 'Data_Value_Type',
#        'Data_Value', 'Data_Value_Alt', 'Data_Value_Footnote_Symbol',
#        'Data_Value_Footnote', 'Low_Confidence_Limit', 'High_Confidence_Limit ',
#        'Sample_Size', 'Total', 'Age(years)', 'Education', 'Gender', 'Income',
#        'Race/Ethnicity', 'GeoLocation', 'ClassID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'LocationID', 'StratificationCategory1',
#        'Stratification1', 'StratificationCategoryId1', 'StratificationID1'],
#       dtype='object')

# %%
# Trim the columns of data to the one we need
DNPAO_sevencols = DNPAO_all.drop(['YearEnd','Datasource',
       'Class', 'Topic', 'Question', 'Data_Value_Unit', 'Data_Value_Type',
       'Data_Value_Alt', 'Data_Value_Footnote_Symbol',
       'Data_Value_Footnote', 'Low_Confidence_Limit', 'High_Confidence_Limit ',
       'Sample_Size', 'Total', 'Age(years)', 'Education', 'Gender', 'Income',
       'Race/Ethnicity', 'GeoLocation', 'ClassID', 'TopicID',
       'DataValueTypeID', 'LocationID', 'StratificationCategory1',
       'StratificationID1'], axis=1)
# DNPAO_sevencols.to_csv("DNPAO_sevencols.csv", index=False)
DNPAO_sevencols
# Out:
#        YearStart LocationAbbr  LocationDesc  Data_Value QuestionID  \
# 0           2011           AL       Alabama        35.2       Q036
# 1           2011           US      National        35.4       Q036
# 2           2011           RI  Rhode Island        32.1       Q036
# 3           2011           US      National        16.9       Q047
# 4           2011           US      National        31.6       Q037
# ...          ...          ...           ...         ...        ...
# 93244       2022           WY       Wyoming        24.5       Q037
# 93245       2022           WY       Wyoming        36.0       Q047
# 93246       2022           WY       Wyoming        35.2       Q036
# 93247       2022           WY       Wyoming        35.3       Q037
# 93248       2022           WY       Wyoming        41.0       Q036
#
#                      Stratification1 StratificationCategoryId1
# 0                            25 - 34                     AGEYR
# 1      American Indian/Alaska Native                      RACE
# 2                              Other                      RACE
# 3                            18 - 24                     AGEYR
# 4                  Less than $15,000                       INC
# ...                              ...                       ...
# 93244              Less than $15,000                       INC
# 93245          Less than high school                       EDU
# 93246                        35 - 44                     AGEYR
# 93247              $35,000 - $49,999                       INC
# 93248          Less than high school                       EDU
#
# [93249 rows x 7 columns]

# %%
import json

# Load JSON data from file
with open("Q037_2022_overall.geojson", "r") as file:
    data = json.load(file)

# Iterate through features and convert specific data_value to float
for feature in data["features"]:
    # Assuming data_value is a string
    feature["properties"]["data_value"] = float(feature["properties"]["data_value"])

# Print modified GeoJSON data
print(json.dumps(data, indent=4))

# Write modified GeoJSON data to a new file
output_file_path = "modified_geojson.geojson"
with open(output_file_path, "w") as output_file:
    json.dump(data, output_file, indent=4)

print(f"Modified GeoJSON data has been saved to {output_file_path}")
# Out:
# {
#     "type": "FeatureCollection",
#     "features": [
#         {
#             "type": "Feature",
#             "geometry": null,
#             "properties": {
#                 "question": "Percent of adults aged 18 years and older who have an overweight classification",
#                 "low_confidence_limit": "33.8",
#                 "data_value_unit": null,
#                 "data_value": 34.1,
#                 "geolocation_address": null,
#                 "geolocation_zip": null,
#                 "locationid": "59",
#                 "age_years": null,
#                 "geolocation_state": null,
#                 "sample_size": "387549",
#                 "total": "Total",
#                 "stratificationcategory1": "Total",
#                 "high_confidence_limit": "34.4",
#                 "classid": "OWS",
#                 "education": null,
#                 "income": null,
#                 "questionid": "Q037",
#                 "locationdesc": "National",
#                 "stratification1": "Total",
#                 "data_value_footnote": null,
#                 "data_value_type": "Value",
#                 "data_value_footnote_symbol": null,
#                 "geolocation_city": null,
#                 "stratificationid1": "OVERALL",
#                 "class": "Obesity / Weight Status",
#                 "datavaluetypeid": "VALUE",
#                 "topic": "Obesity / Weight Status",
#                 "yearend": "2022",
#                 "race_ethnicity": null,
#                 "topicid": "OWS1",
#                 "data_value_alt": "34.1",
#                 "datasource": "BRFSS",
#                 "yearstart": "2022",
#                 "locationabbr": "US",
#                 "stratificationcategoryid1": "OVR",
#                 "gender": null
#             }
#         },
#         {
#             "type": "Feature",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -86.63186076199969,
#                     32.84057112200048
#                 ]
#             },
#             "properties": {
#                 "question": "Percent of adults aged 18 years and older who have an overweight classification",
#                 "low_confidence_limit": "31.7",
#                 "data_value_unit": null,
#                 "data_value": 33.7,
#                 "geolocation_address": "",
#                 "geolocation_zip": "",
#                 "locationid": "01",
#                 "age_years": null,
#                 "geolocation_state": "",
#                 "sample_size": "4208",
#                 "total": "Total",
#                 "stratificationcategory1": "Total",
#                 "high_confidence_limit": "35.7",
#                 "classid": "OWS",
#                 "education": null,
#                 "income": null,
#                 "questionid": "Q037",
#                 "locationdesc": "Alabama",
#                 "stratification1": "Total",
#                 "data_value_footnote": null,
#                 "data_value_type": "Value",
#                 "data_value_footnote_symbol": null,
#                 "geolocation_city": "",
#                 "stratificationid1": "OVERALL",
#                 "class": "Obesity / Weight Status",
#                 "datavaluetypeid": "VALUE",
#                 "topic": "Obesity / Weight Status",
#                 "yearend": "2022",
#                 "race_ethnicity": null,
#                 "topicid": "OWS1",
#                 "data_value_alt": "33.7",
#                 "datasource": "BRFSS",
#                 "yearstart": "2022",
#                 "locationabbr": "AL",
#                 "stratificationcategoryid1": "OVR",
#                 "gender": null
#             }
#         },
#         {
#             "type": "Feature",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -72.64984095199964,
#                     41.56266102000046
#                 ]
#             },
#             "properties": {
#                 "question": "Percent of adults aged 18 years and older who have an overweight classification",
#                 "low_confidence_limit": "34.0",
#                 "data_value_unit": null,
#                 "data_value": 35.6,
#                 "geolocation_address": "",
#                 "geolocation_zip": "",
#                 "locationid": "09",
#                 "age_years": null,
#                 "geolocation_state": "",
#                 "sample_size": "8212",
#                 "total": "Total",
#                 "stratificationcategory1": "Total",
#                 "high_confidence_limit": "37.1",
#                 "classid": "OWS",
#                 "education": null,
#                 "income": null,
#                 "questionid": "Q037",
#                 "locationdesc": "Connecticut",
#                 "stratification1": "Total",
#                 "data_value_footnote": null,
#                 "data_value_type": "Value",
#                 "data_value_footnote_symbol": null,
#                 "geolocation_city": "",
#                 "stratificationid1": "OVERALL",
#                 "class": "Obesity / Weight Status",
#                 "datavaluetypeid": "VALUE",
#                 "topic": "Obesity / Weight Status",
#                 "yearend": "2022",
#                 "race_ethnicity": null,
#                 "topicid": "OWS1",
#                 "data_value_alt": "35.6",
#                 "datasource": "BRFSS",
#                 "yearstart": "2022",
#                 "locationabbr": "CT",
#                 "stratificationcategoryid1": "OVR",
#                 "gender": null
#             }
#         },
#         {
#             "type": "Feature",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -147.72205903599973,
#                     64.84507995700051
#                 ]
#             },
#             "properties": {
#                 "question": "Percent of adults aged 18 years and older who have an overweight classification",
#                 "low_confidence_limit": "34.6",
#                 "data_value_unit": null,
#                 "data_value": 36.4,
#                 "geolocation_address": "",
#                 "geolocation_zip": "",
#                 "locationid": "02",
#                 "age_years": null,
#                 "geolocation_state": "",
#                 "sample_size": "5273",
#                 "total": "Total",
#                 "stratificationcategory1": "Total",
#                 "high_confidence_limit": "38.3",
#                 "classid": "OWS",
#                 "education": null,
#                 "income": null,
#                 "questionid": "Q037",
#                 "locationdesc": "Alaska",
#                 "stratification1": "Total",
#                 "data_value_footnote": null,
#                 "data_value_type": "Value",
#                 "data_value_footnote_symbol": null,
#                 "geolocation_city": "",
#                 "stratificationid1": "OVERALL",
#                 "class": "Obesity / Weight Status",
#                 "datavaluetypeid": "VALUE",
#                 "topic": "Obesity / Weight Status",
#                 "yearend": "2022",
#                 "race_ethnicity": null,
#                 "topicid": "OWS1",
#                 "data_value_alt": "36.4",
#                 "datasource": "BRFSS",
#                 "yearstart": "2022",
#                 "locationabbr": "AK",
#                 "stratificationcategoryid1": "OVR",
#                 "gender": null
#             }
#         },
#         {
#             "type": "Feature",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -92.27449074299966,
#                     34.74865012400045
#                 ]
#             },
#             "properties": {
#                 "question": "Percent of adults aged 18 years and older who have an overweight classification",
#                 "low_confidence_limit": "31.9",
#                 "data_value_unit": null,
#                 "data_value": 33.6,
#                 "geolocation_address": "",
#                 "geolocation_zip": "",
#                 "locationid": "05",
#                 "age_years": null,
#                 "geolocation_state": "",
#                 "sample_size": "4652",
#                 "total": "Total",
#                 "stratificationcategory1": "Total",
#                 "high_confidence_limit": "35.5",
#                 "classid": "OWS",
#                 "education": null,
#                 "income": null,
#                 "questionid": "Q037",
#                 "locationdesc": "Arkansas",
#                 "stratification1": "Total",
#                 "data_value_footnote": null,
#                 "data_value_type": "Value",
#                 "data_value_footnote_symbol": null,
#                 "geolocation_city": "",
#                 "stratificationid1": "OVERALL",
#                 "class": "Obesity / Weight Status",
#                 "datavaluetypeid": "VALUE",
#                 "topic": "Obesity / Weight Status",
#                 "yearend": "2022",
#                 "race_ethnicity": null,
#                 "topicid": "OWS1",
#                 "data_value_alt": "33.6",
#                 "datasource": "BRFSS",
#                 "yearstart": "2022",
#                 "locationabbr": "AR",
#                 "stratificationcategoryid1": "OVR",
#                 "gender": null
#             }
#         },
#         {
#             "type": "Feature",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -111.76381127699972,
#                     34.865970280000454
#                 ]
#             },
#             "properties": {
#                 "question": "Percent of adults aged 18 years and older who have an overweight classification",
#                 "low_confidence_limit": "31.9",
#                 "data_value_unit": null,
#                 "data_value": 33.5,
#                 "geolocation_address": "",
#                 "geolocation_zip": "",
#                 "locationid": "04",
#                 "age_years": null,
#                 "geolocation_state": "",
#                 "sample_size": "9180",
#                 "total": "Total",
#                 "stratificationcategory1": "Total",
#                 "high_confidence_limit": "35.1",
#                 "classid": "OWS",
#                 "education": null,
#                 "income": null,
#                 "questionid": "Q037",
#                 "locationdesc": "Arizona",
#                 "stratification1": "Total",
#                 "data_value_footnote": null,
#                 "data_value_type": "Value",
#                 "data_value_footnote_symbol": null,
#                 "geolocation_city": "",
#                 "stratificationid1": "OVERALL",
#                 "class": "Obesity / Weight Status",
#                 "datavaluetypeid": "VALUE",
#                 "topic": "Obesity / Weight Status",
#                 "yearend": "2022",
#                 "race_ethnicity": null,
#                 "topicid": "OWS1",
#                 "data_value_alt": "33.5",
#                 "datasource": "BRFSS",
#                 "yearstart": "2022",
#                 "locationabbr": "AZ",
#                 "stratificationcategoryid1": "OVR",
#                 "gender": null
#             }
#         },
#         {
#             "type": "Feature",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -120.99999953799971,
#                     37.63864012300047
#                 ]
#             },
#             "properties": {
#                 "question": "Percent of adults aged 18 years and older who have an overweight classification",
#                 "low_confidence_limit": "33.3",
#                 "data_value_unit": null,
#                 "data_value": 34.7,
#                 "geolocation_address": "",
#                 "geolocation_zip": "",
#                 "locationid": "06",
#                 "age_years": null,
#                 "geolocation_state": "",
#                 "sample_size": "9466",
#                 "total": "Total",
#                 "stratificationcategory1": "Total",
#                 "high_confidence_limit": "36.1",
#                 "classid": "OWS",
#                 "education": null,
#                 "income": null,
#                 "questionid": "Q037",
#                 "locationdesc": "California",
#                 "stratification1": "Total",
#                 "data_value_footnote": null,
#                 "data_value_type": "Value",
#                 "data_value_footnote_symbol": null,
#                 "geolocation_city": "",
#                 "stratificationid1": "OVERALL",
#                 "class": "Obesity / Weight Status",
#                 "datavaluetypeid": "VALUE",
#                 "topic": "Obesity / Weight Status",
#                 "yearend": "2022",
#                 "race_ethnicity": null,
#                 "topicid": "OWS1",
#                 "data_value_alt": "34.7",
#                 "datasource": "BRFSS",
#                 "yearstart": "2022",
#                 "locationabbr": "CA",
#                 "stratificationcategoryid1": "OVR",
#                 "gender": null
#             }
#         },
#         {
#             "type": "Feature",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -106.13361092099967,
#                     38.843840757000464
#                 ]
#             },
#             "properties": {
#                 "question": "Percent of adults aged 18 years and older who have an overweight classification",
#                 "low_confidence_limit": "34.3",
#                 "data_value_unit": null,
#                 "data_value": 35.6,
#                 "geolocation_address": "",
#                 "geolocation_zip": "",
#                 "locationid": "08",
#                 "age_years": null,
#                 "geolocation_state": "",
#                 "sample_size": "8388",
#                 "total": "Total",
#                 "stratificationcategory1": "Total",
#                 "high_confidence_limit": "36.9",
#                 "classid": "OWS",
#                 "education": null,
#                 "income": null,
#                 "questionid": "Q037",
#                 "locationdesc": "Colorado",
#                 "stratification1": "Total",
#                 "data_value_footnote": null,
#                 "data_value_type": "Value",
#                 "data_value_footnote_symbol": null,
#                 "geolocation_city": "",
#                 "stratificationid1": "OVERALL",
#                 "class": "Obesity / Weight Status",
#                 "datavaluetypeid": "VALUE",
#                 "topic": "Obesity / Weight Status",
#                 "yearend": "2022",
#                 "race_ethnicity": null,
#                 "topicid": "OWS1",
#                 "data_value_alt": "35.6",
#                 "datasource": "BRFSS",
#                 "yearstart": "2022",
#                 "locationabbr": "CO",
#                 "stratificationcategoryid1": "OVR",
#                 "gender": null
#             }
#         },
#         {
#             "type": "Feature",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -77.03196112699965,
#                     38.89037138500049
#                 ]
#             },
#             "properties": {
#                 "question": "Percent of adults aged 18 years and older who have an overweight classification",
#                 "low_confidence_limit": "28.7",
#                 "data_value_unit": null,
#                 "data_value": 30.9,
#                 "geolocation_address": "",
#                 "geolocation_zip": "",
#                 "locationid": "11",
#                 "age_years": null,
#                 "geolocation_state": "",
#                 "sample_size": "2882",
#                 "total": "Total",
#                 "stratificationcategory1": "Total",
#                 "high_confidence_limit": "33.1",
#                 "classid": "OWS",
#                 "education": null,
#                 "income": null,
#                 "questionid": "Q037",
#                 "locationdesc": "District of Columbia",
#                 "stratification1": "Total",
#                 "data_value_footnote": null,
#                 "data_value_type": "Value",
#                 "data_value_footnote_symbol": null,
#                 "geolocation_city": "",
#                 "stratificationid1": "OVERALL",
#                 "class": "Obesity / Weight Status",
#                 "datavaluetypeid": "VALUE",
#                 "topic": "Obesity / Weight Status",
#                 "yearend": "2022",
#                 "race_ethnicity": null,
#                 "topicid": "OWS1",
#                 "data_value_alt": "30.9",
#                 "datasource": "BRFSS",
#                 "yearstart": "2022",
#                 "locationabbr": "DC",
#                 "stratificationcategoryid1": "OVR",
#                 "gender": null
#             }
#         },
#         {
#             "type": "Feature",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -75.57774116799965,
#                     39.008830667000495
#                 ]
#             },
#             "properties": {
#                 "question": "Percent of adults aged 18 years and older who have an overweight classification",
#                 "low_confidence_limit": "31.9",
#                 "data_value_unit": null,
#                 "data_value": 33.9,
#                 "geolocation_address": "",
#                 "geolocation_zip": "",
#                 "locationid": "10",
#                 "age_years": null,
#                 "geolocation_state": "",
#                 "sample_size": "3550",
#                 "total": "Total",
#                 "stratificationcategory1": "Total",
#                 "high_confidence_limit": "36.1",
#                 "classid": "OWS",
#                 "education": null,
#                 "income": null,
#                 "questionid": "Q037",
#                 "locationdesc": "Delaware",
#                 "stratification1": "Total",
#                 "data_value_footnote": null,
#                 "data_value_type": "Value",
#                 "data_value_footnote_symbol": null,
#                 "geolocation_city": "",
#                 "stratificationid1": "OVERALL",
#                 "class": "Obesity / Weight Status",
#                 "datavaluetypeid": "VALUE",
#                 "topic": "Obesity / Weight Status",
#                 "yearend": "2022",
#                 "race_ethnicity": null,
#                 "topicid": "OWS1",
#                 "data_value_alt": "33.9",
#                 "datasource": "BRFSS",
#                 "yearstart": "2022",
#                 "locationabbr": "DE",
#                 "stratificationcategoryid1": "OVR",
#                 "gender": null
#             }
#         },
#         {
#             "type": "Feature",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -81.92896053899966,
#                     28.932040377000476
#                 ]
#             },
#             "properties": {
#                 "question": "Percent of adults aged 18 years and older who have an overweight classification",
#                 "low_confidence_limit": "32.7",
#                 "data_value_unit": null,
#                 "data_value": 34.5,
#                 "geolocation_address": "",
#                 "geolocation_zip": "",
#                 "locationid": "12",
#                 "age_years": null,
#                 "geolocation_state": "",
#                 "sample_size": "11805",
#                 "total": "Total",
#                 "stratificationcategory1": "Total",
#                 "high_confidence_limit": "36.3",
#                 "classid": "OWS",
#                 "education": null,
#                 "income": null,
#                 "questionid": "Q037",
#                 "locationdesc": "Florida",
#                 "stratification1": "Total",
#                 "data_value_footnote": null,
#                 "data_value_type": "Value",
#                 "data_value_footnote_symbol": null,
#                 "geolocation_city": "",
#                 "stratificationid1": "OVERALL",
#                 "class": "Obesity / Weight Status",
#                 "datavaluetypeid": "VALUE",
#                 "topic": "Obesity / Weight Status",
#                 "yearend": "2022",
#                 "race_ethnicity": null,
#                 "topicid": "OWS1",
#                 "data_value_alt": "34.5",
#                 "datasource": "BRFSS",
#                 "yearstart": "2022",
#                 "locationabbr": "FL",
#                 "stratificationcategoryid1": "OVR",
#                 "gender": null
#             }
#         },
#         {
#             "type": "Feature",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -99.42677020599967,
#                     31.827240407000488
#                 ]
#             },
#             "properties": {
#                 "question": "Percent of adults aged 18 years and older who have an overweight classification",
#                 "low_confidence_limit": "33.1",
#                 "data_value_unit": null,
#                 "data_value": 34.7,
#                 "geolocation_address": "",
#                 "geolocation_zip": "",
#                 "locationid": "48",
#                 "age_years": null,
#                 "geolocation_state": "",
#                 "sample_size": "12204",
#                 "total": "Total",
#                 "stratificationcategory1": "Total",
#                 "high_confidence_limit": "36.2",
#                 "classid": "OWS",
#                 "education": null,
#                 "income": null,
#                 "questionid": "Q037",
#                 "locationdesc": "Texas",
#                 "stratification1": "Total",
#                 "data_value_footnote": null,
#                 "data_value_type": "Value",
#                 "data_value_footnote_symbol": null,
#                 "geolocation_city": "",
#                 "stratificationid1": "OVERALL",
#                 "class": "Obesity / Weight Status",
#                 "datavaluetypeid": "VALUE",
#                 "topic": "Obesity / Weight Status",
#                 "yearend": "2022",
#                 "race_ethnicity": null,
#                 "topicid": "OWS1",
#                 "data_value_alt": "34.7",
#                 "datasource": "BRFSS",
#                 "yearstart": "2022",
#                 "locationabbr": "TX",
#                 "stratificationcategoryid1": "OVR",
#                 "gender": null
#             }
#         },
#         {
#             "type": "Feature",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -83.62758034599966,
#                     32.83968109300048
#                 ]
#             },
#             "properties": {
#                 "question": "Percent of adults aged 18 years and older who have an overweight classification",
#                 "low_confidence_limit": "30.4",
#                 "data_value_unit": null,
#                 "data_value": 31.9,
#                 "geolocation_address": "",
#                 "geolocation_zip": "",
#                 "locationid": "13",
#                 "age_years": null,
#                 "geolocation_state": "",
#                 "sample_size": "8018",
#                 "total": "Total",
#                 "stratificationcategory1": "Total",
#                 "high_confidence_limit": "33.4",
#                 "classid": "OWS",
#                 "education": null,
#                 "income": null,
#                 "questionid": "Q037",
#                 "locationdesc": "Georgia",
#                 "stratification1": "Total",
#                 "data_value_footnote": null,
#                 "data_value_type": "Value",
#                 "data_value_footnote_symbol": null,
#                 "geolocation_city": "",
#                 "stratificationid1": "OVERALL",
#                 "class": "Obesity / Weight Status",
#                 "datavaluetypeid": "VALUE",
#                 "topic": "Obesity / Weight Status",
#                 "yearend": "2022",
#                 "race_ethnicity": null,
#                 "topicid": "OWS1",
#                 "data_value_alt": "31.9",
#                 "datasource": "BRFSS",
#                 "yearstart": "2022",
#                 "locationabbr": "GA",
#                 "stratificationcategoryid1": "OVR",
#                 "gender": null
#             }
#         },
#         {
#             "type": "Feature",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     144.793731,
#                     13.444304
#                 ]
#             },
#             "properties": {
#                 "question": "Percent of adults aged 18 years and older who have an overweight classification",
#                 "low_confidence_limit": "30.4",
#                 "data_value_unit": null,
#                 "data_value": 34.5,
#                 "geolocation_address": "",
#                 "geolocation_zip": "",
#                 "locationid": "66",
#                 "age_years": null,
#                 "geolocation_state": "",
#                 "sample_size": "2103",
#                 "total": "Total",
#                 "stratificationcategory1": "Total",
#                 "high_confidence_limit": "38.8",
#                 "classid": "OWS",
#                 "education": null,
#                 "income": null,
#                 "questionid": "Q037",
#                 "locationdesc": "Guam",
#                 "stratification1": "Total",
#                 "data_value_footnote": null,
#                 "data_value_type": "Value",
#                 "data_value_footnote_symbol": null,
#                 "geolocation_city": "",
#                 "stratificationid1": "OVERALL",
#                 "class": "Obesity / Weight Status",
#                 "datavaluetypeid": "VALUE",
#                 "topic": "Obesity / Weight Status",
#                 "yearend": "2022",
#                 "race_ethnicity": null,
#                 "topicid": "OWS1",
#                 "data_value_alt": "34.5",
#                 "datasource": "BRFSS",
#                 "yearstart": "2022",
#                 "locationabbr": "GU",
#                 "stratificationcategoryid1": "OVR",
#                 "gender": null
#             }
#         },
#         {
#             "type": "Feature",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -157.85774940299973,
#                     21.304850435000446
#                 ]
#             },
#             "properties": {
#                 "question": "Percent of adults aged 18 years and older who have an overweight classification",
#                 "low_confidence_limit": "32.3",
#                 "data_value_unit": null,
#                 "data_value": 33.8,
#                 "geolocation_address": "",
#                 "geolocation_zip": "",
#                 "locationid": "15",
#                 "age_years": null,
#                 "geolocation_state": "",
#                 "sample_size": "7280",
#                 "total": "Total",
#                 "stratificationcategory1": "Total",
#                 "high_confidence_limit": "35.4",
#                 "classid": "OWS",
#                 "education": null,
#                 "income": null,
#                 "questionid": "Q037",
#                 "locationdesc": "Hawaii",
#                 "stratification1": "Total",
#                 "data_value_footnote": null,
#                 "data_value_type": "Value",
#                 "data_value_footnote_symbol": null,
#                 "geolocation_city": "",
#                 "stratificationid1": "OVERALL",
#                 "class": "Obesity / Weight Status",
#                 "datavaluetypeid": "VALUE",
#                 "topic": "Obesity / Weight Status",
#                 "yearend": "2022",
#                 "race_ethnicity": null,
#                 "topicid": "OWS1",
#                 "data_value_alt": "33.8",
#                 "datasource": "BRFSS",
#                 "yearstart": "2022",
#                 "locationabbr": "HI",
#                 "stratificationcategoryid1": "OVR",
#                 "gender": null
#             }
#         },
#         {
#             "type": "Feature",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -93.81649055599968,
#                     42.46940091300047
#                 ]
#             },
#             "properties": {
#                 "question": "Percent of adults aged 18 years and older who have an overweight classification",
#                 "low_confidence_limit": "32.5",
#                 "data_value_unit": null,
#                 "data_value": 33.8,
#                 "geolocation_address": "",
#                 "geolocation_zip": "",
#                 "locationid": "19",
#                 "age_years": null,
#                 "geolocation_state": "",
#                 "sample_size": "8114",
#                 "total": "Total",
#                 "stratificationcategory1": "Total",
#                 "high_confidence_limit": "35.2",
#                 "classid": "OWS",
#                 "education": null,
#                 "income": null,
#                 "questionid": "Q037",
#                 "locationdesc": "Iowa",
#                 "stratification1": "Total",
#                 "data_value_footnote": null,
#                 "data_value_type": "Value",
#                 "data_value_footnote_symbol": null,
#                 "geolocation_city": "",
#                 "stratificationid1": "OVERALL",
#                 "class": "Obesity / Weight Status",
#                 "datavaluetypeid": "VALUE",
#                 "topic": "Obesity / Weight Status",
#                 "yearend": "2022",
#                 "race_ethnicity": null,
#                 "topicid": "OWS1",
#                 "data_value_alt": "33.8",
#                 "datasource": "BRFSS",
#                 "yearstart": "2022",
#                 "locationabbr": "IA",
#                 "stratificationcategoryid1": "OVR",
#                 "gender": null
#             }
#         },
#         {
#             "type": "Feature",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -114.3637300419997,
#                     43.682630005000476
#                 ]
#             },
#             "properties": {
#                 "question": "Percent of adults aged 18 years and older who have an overweight classification",
#                 "low_confidence_limit": "33.9",
#                 "data_value_unit": null,
#                 "data_value": 35.4,
#                 "geolocation_address": "",
#                 "geolocation_zip": "",
#                 "locationid": "16",
#                 "age_years": null,
#                 "geolocation_state": "",
#                 "sample_size": "5697",
#                 "total": "Total",
#                 "stratificationcategory1": "Total",
#                 "high_confidence_limit": "36.9",
#                 "classid": "OWS",
#                 "education": null,
#                 "income": null,
#                 "questionid": "Q037",
#                 "locationdesc": "Idaho",
#                 "stratification1": "Total",
#                 "data_value_footnote": null,
#                 "data_value_type": "Value",
#                 "data_value_footnote_symbol": null,
#                 "geolocation_city": "",
#                 "stratificationid1": "OVERALL",
#                 "class": "Obesity / Weight Status",
#                 "datavaluetypeid": "VALUE",
#                 "topic": "Obesity / Weight Status",
#                 "yearend": "2022",
#                 "race_ethnicity": null,
#                 "topicid": "OWS1",
#                 "data_value_alt": "35.4",
#                 "datasource": "BRFSS",
#                 "yearstart": "2022",
#                 "locationabbr": "ID",
#                 "stratificationcategoryid1": "OVR",
#                 "gender": null
#             }
#         },
#         {
#             "type": "Feature",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -88.99771017799969,
#                     40.48501028300046
#                 ]
#             },
#             "properties": {
#                 "question": "Percent of adults aged 18 years and older who have an overweight classification",
#                 "low_confidence_limit": "32.0",
#                 "data_value_unit": null,
#                 "data_value": 33.9,
#                 "geolocation_address": "",
#                 "geolocation_zip": "",
#                 "locationid": "17",
#                 "age_years": null,
#                 "geolocation_state": "",
#                 "sample_size": "3730",
#                 "total": "Total",
#                 "stratificationcategory1": "Total",
#                 "high_confidence_limit": "35.8",
#                 "classid": "OWS",
#                 "education": null,
#                 "income": null,
#                 "questionid": "Q037",
#                 "locationdesc": "Illinois",
#                 "stratification1": "Total",
#                 "data_value_footnote": null,
#                 "data_value_type": "Value",
#                 "data_value_footnote_symbol": null,
#                 "geolocation_city": "",
#                 "stratificationid1": "OVERALL",
#                 "class": "Obesity / Weight Status",
#                 "datavaluetypeid": "VALUE",
#                 "topic": "Obesity / Weight Status",
#                 "yearend": "2022",
#                 "race_ethnicity": null,
#                 "topicid": "OWS1",
#                 "data_value_alt": "33.9",
#                 "datasource": "BRFSS",
#                 "yearstart": "2022",
#                 "locationabbr": "IL",
#                 "stratificationcategoryid1": "OVR",
#                 "gender": null
#             }
#         },
#         {
#             "type": "Feature",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -86.14996019399968,
#                     39.766910452000445
#                 ]
#             },
#             "properties": {
#                 "question": "Percent of adults aged 18 years and older who have an overweight classification",
#                 "low_confidence_limit": "32.1",
#                 "data_value_unit": null,
#                 "data_value": 33.3,
#                 "geolocation_address": "",
#                 "geolocation_zip": "",
#                 "locationid": "18",
#                 "age_years": null,
#                 "geolocation_state": "",
#                 "sample_size": "8834",
#                 "total": "Total",
#                 "stratificationcategory1": "Total",
#                 "high_confidence_limit": "34.6",
#                 "classid": "OWS",
#                 "education": null,
#                 "income": null,
#                 "questionid": "Q037",
#                 "locationdesc": "Indiana",
#                 "stratification1": "Total",
#                 "data_value_footnote": null,
#                 "data_value_type": "Value",
#                 "data_value_footnote_symbol": null,
#                 "geolocation_city": "",
#                 "stratificationid1": "OVERALL",
#                 "class": "Obesity / Weight Status",
#                 "datavaluetypeid": "VALUE",
#                 "topic": "Obesity / Weight Status",
#                 "yearend": "2022",
#                 "race_ethnicity": null,
#                 "topicid": "OWS1",
#                 "data_value_alt": "33.3",
#                 "datasource": "BRFSS",
#                 "yearstart": "2022",
#                 "locationabbr": "IN",
#                 "stratificationcategoryid1": "OVR",
#                 "gender": null
#             }
#         },
#         {
#             "type": "Feature",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -98.20078122699965,
#                     38.34774030000045
#                 ]
#             },
#             "properties": {
#                 "question": "Percent of adults aged 18 years and older who have an overweight classification",
#                 "low_confidence_limit": "32.2",
#                 "data_value_unit": null,
#                 "data_value": 33.4,
#                 "geolocation_address": "",
#                 "geolocation_zip": "",
#                 "locationid": "20",
#                 "age_years": null,
#                 "geolocation_state": "",
#                 "sample_size": "10179",
#                 "total": "Total",
#                 "stratificationcategory1": "Total",
#                 "high_confidence_limit": "34.7",
#                 "classid": "OWS",
#                 "education": null,
#                 "income": null,
#                 "questionid": "Q037",
#                 "locationdesc": "Kansas",
#                 "stratification1": "Total",
#                 "data_value_footnote": null,
#                 "data_value_type": "Value",
#                 "data_value_footnote_symbol": null,
#                 "geolocation_city": "",
#                 "stratificationid1": "OVERALL",
#                 "class": "Obesity / Weight Status",
#                 "datavaluetypeid": "VALUE",
#                 "topic": "Obesity / Weight Status",
#                 "yearend": "2022",
#                 "race_ethnicity": null,
#                 "topicid": "OWS1",
#                 "data_value_alt": "33.4",
#                 "datasource": "BRFSS",
#                 "yearstart": "2022",
#                 "locationabbr": "KS",
#                 "stratificationcategoryid1": "OVR",
#                 "gender": null
#             }
#         },
#         {
#             "type": "Feature",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -84.77497104799966,
#                     37.645970271000465
#                 ]
#             },
#             "properties": {
#                 "question": "Percent of adults aged 18 years and older who have an overweight classification",
#                 "low_confidence_limit": "32.0",
#                 "data_value_unit": null,
#                 "data_value": 34.1,
#                 "geolocation_address": "",
#                 "geolocation_zip": "",
#                 "locationid": "21",
#                 "age_years": null,
#                 "geolocation_state": "",
#                 "sample_size": "3680",
#                 "total": "Total",
#                 "stratificationcategory1": "Total",
#                 "high_confidence_limit": "36.4",
#                 "classid": "OWS",
#                 "education": null,
#                 "income": null,
#                 "questionid": "Q037",
#                 "locationdesc": "Kentucky",
#                 "stratification1": "Total",
#                 "data_value_footnote": null,
#                 "data_value_type": "Value",
#                 "data_value_footnote_symbol": null,
#                 "geolocation_city": "",
#                 "stratificationid1": "OVERALL",
#                 "class": "Obesity / Weight Status",
#                 "datavaluetypeid": "VALUE",
#                 "topic": "Obesity / Weight Status",
#                 "yearend": "2022",
#                 "race_ethnicity": null,
#                 "topicid": "OWS1",
#                 "data_value_alt": "34.1",
#                 "datasource": "BRFSS",
#                 "yearstart": "2022",
#                 "locationabbr": "KY",
#                 "stratificationcategoryid1": "OVR",
#                 "gender": null
#             }
#         },
#         {
#             "type": "Feature",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -92.44568007099969,
#                     31.31266064400046
#                 ]
#             },
#             "properties": {
#                 "question": "Percent of adults aged 18 years and older who have an overweight classification",
#                 "low_confidence_limit": "30.0",
#                 "data_value_unit": null,
#                 "data_value": 31.7,
#                 "geolocation_address": "",
#                 "geolocation_zip": "",
#                 "locationid": "22",
#                 "age_years": null,
#                 "geolocation_state": "",
#                 "sample_size": "5117",
#                 "total": "Total",
#                 "stratificationcategory1": "Total",
#                 "high_confidence_limit": "33.4",
#                 "classid": "OWS",
#                 "education": null,
#                 "income": null,
#                 "questionid": "Q037",
#                 "locationdesc": "Louisiana",
#                 "stratification1": "Total",
#                 "data_value_footnote": null,
#                 "data_value_type": "Value",
#                 "data_value_footnote_symbol": null,
#                 "geolocation_city": "",
#                 "stratificationid1": "OVERALL",
#                 "class": "Obesity / Weight Status",
#                 "datavaluetypeid": "VALUE",
#                 "topic": "Obesity / Weight Status",
#                 "yearend": "2022",
#                 "race_ethnicity": null,
#                 "topicid": "OWS1",
#                 "data_value_alt": "31.7",
#                 "datasource": "BRFSS",
#                 "yearstart": "2022",
#                 "locationabbr": "LA",
#                 "stratificationcategoryid1": "OVR",
#                 "gender": null
#             }
#         },
#         {
#             "type": "Feature",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -72.08269067499964,
#                     42.27687047000046
#                 ]
#             },
#             "properties": {
#                 "question": "Percent of adults aged 18 years and older who have an overweight classification",
#                 "low_confidence_limit": "33.4",
#                 "data_value_unit": null,
#                 "data_value": 34.7,
#                 "geolocation_address": "",
#                 "geolocation_zip": "",
#                 "locationid": "25",
#                 "age_years": null,
#                 "geolocation_state": "",
#                 "sample_size": "9701",
#                 "total": "Total",
#                 "stratificationcategory1": "Total",
#                 "high_confidence_limit": "36.0",
#                 "classid": "OWS",
#                 "education": null,
#                 "income": null,
#                 "questionid": "Q037",
#                 "locationdesc": "Massachusetts",
#                 "stratification1": "Total",
#                 "data_value_footnote": null,
#                 "data_value_type": "Value",
#                 "data_value_footnote_symbol": null,
#                 "geolocation_city": "",
#                 "stratificationid1": "OVERALL",
#                 "class": "Obesity / Weight Status",
#                 "datavaluetypeid": "VALUE",
#                 "topic": "Obesity / Weight Status",
#                 "yearend": "2022",
#                 "race_ethnicity": null,
#                 "topicid": "OWS1",
#                 "data_value_alt": "34.7",
#                 "datasource": "BRFSS",
#                 "yearstart": "2022",
#                 "locationabbr": "MA",
#                 "stratificationcategoryid1": "OVR",
#                 "gender": null
#             }
#         },
#         {
#             "type": "Feature",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -76.60926011099963,
#                     39.29058096400047
#                 ]
#             },
#             "properties": {
#                 "question": "Percent of adults aged 18 years and older who have an overweight classification",
#                 "low_confidence_limit": "33.2",
#                 "data_value_unit": null,
#                 "data_value": 34.4,
#                 "geolocation_address": "",
#                 "geolocation_zip": "",
#                 "locationid": "24",
#                 "age_years": null,
#                 "geolocation_state": "",
#                 "sample_size": "14263",
#                 "total": "Total",
#                 "stratificationcategory1": "Total",
#                 "high_confidence_limit": "35.7",
#                 "classid": "OWS",
#                 "education": null,
#                 "income": null,
#                 "questionid": "Q037",
#                 "locationdesc": "Maryland",
#                 "stratification1": "Total",
#                 "data_value_footnote": null,
#                 "data_value_type": "Value",
#                 "data_value_footnote_symbol": null,
#                 "geolocation_city": "",
#                 "stratificationid1": "OVERALL",
#                 "class": "Obesity / Weight Status",
#                 "datavaluetypeid": "VALUE",
#                 "topic": "Obesity / Weight Status",
#                 "yearend": "2022",
#                 "race_ethnicity": null,
#                 "topicid": "OWS1",
#                 "data_value_alt": "34.4",
#                 "datasource": "BRFSS",
#                 "yearstart": "2022",
#                 "locationabbr": "MD",
#                 "stratificationcategoryid1": "OVR",
#                 "gender": null
#             }
#         },
#         {
#             "type": "Feature",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -68.98503133599962,
#                     45.254228894000505
#                 ]
#             },
#             "properties": {
#                 "question": "Percent of adults aged 18 years and older who have an overweight classification",
#                 "low_confidence_limit": "31.7",
#                 "data_value_unit": null,
#                 "data_value": 33.0,
#                 "geolocation_address": "",
#                 "geolocation_zip": "",
#                 "locationid": "23",
#                 "age_years": null,
#                 "geolocation_state": "",
#                 "sample_size": "9780",
#                 "total": "Total",
#                 "stratificationcategory1": "Total",
#                 "high_confidence_limit": "34.4",
#                 "classid": "OWS",
#                 "education": null,
#                 "income": null,
#                 "questionid": "Q037",
#                 "locationdesc": "Maine",
#                 "stratification1": "Total",
#                 "data_value_footnote": null,
#                 "data_value_type": "Value",
#                 "data_value_footnote_symbol": null,
#                 "geolocation_city": "",
#                 "stratificationid1": "OVERALL",
#                 "class": "Obesity / Weight Status",
#                 "datavaluetypeid": "VALUE",
#                 "topic": "Obesity / Weight Status",
#                 "yearend": "2022",
#                 "race_ethnicity": null,
#                 "topicid": "OWS1",
#                 "data_value_alt": "33.0",
#                 "datasource": "BRFSS",
#                 "yearstart": "2022",
#                 "locationabbr": "ME",
#                 "stratificationcategoryid1": "OVR",
#                 "gender": null
#             }
#         },
#         {
#             "type": "Feature",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -84.71439026999968,
#                     44.6613195430005
#                 ]
#             },
#             "properties": {
#                 "question": "Percent of adults aged 18 years and older who have an overweight classification",
#                 "low_confidence_limit": "31.6",
#                 "data_value_unit": null,
#                 "data_value": 32.8,
#                 "geolocation_address": "",
#                 "geolocation_zip": "",
#                 "locationid": "26",
#                 "age_years": null,
#                 "geolocation_state": "",
#                 "sample_size": "8750",
#                 "total": "Total",
#                 "stratificationcategory1": "Total",
#                 "high_confidence_limit": "34.1",
#                 "classid": "OWS",
#                 "education": null,
#                 "income": null,
#                 "questionid": "Q037",
#                 "locationdesc": "Michigan",
#                 "stratification1": "Total",
#                 "data_value_footnote": null,
#                 "data_value_type": "Value",
#                 "data_value_footnote_symbol": null,
#                 "geolocation_city": "",
#                 "stratificationid1": "OVERALL",
#                 "class": "Obesity / Weight Status",
#                 "datavaluetypeid": "VALUE",
#                 "topic": "Obesity / Weight Status",
#                 "yearend": "2022",
#                 "race_ethnicity": null,
#                 "topicid": "OWS1",
#                 "data_value_alt": "32.8",
#                 "datasource": "BRFSS",
#                 "yearstart": "2022",
#                 "locationabbr": "MI",
# ...
#                 "education": null,
#                 "income": null,
#                 "questionid": "Q037",
#                 "locationdesc": "Tennessee",
#                 "stratification1": "Total",
#                 "data_value_footnote": null,
#                 "data_value_type": "Value",
#                 "data_value_footnote_symbol": null,
#                 "geolocation_city": "",
#                 "stratificationid1": "OVERALL",
#                 "class": "Obesity / Weight Status",
#                 "datavaluetypeid": "VALUE",
#                 "topic": "Obesity / Weight Status",
#                 "yearend": "2022",
#                 "race_ethnicity": null,
#                 "topicid": "OWS1",
#                 "data_value_alt": "32.0",
#                 "datasource": "BRFSS",
#                 "yearstart": "2022",
#                 "locationabbr": "TN",
#                 "stratificationcategoryid1": "OVR",
#                 "gender": null
#             }
#         },
#         {
#             "type": "Feature",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -111.58713063499971,
#                     39.360700171000474
#                 ]
#             },
#             "properties": {
#                 "question": "Percent of adults aged 18 years and older who have an overweight classification",
#                 "low_confidence_limit": "32.9",
#                 "data_value_unit": null,
#                 "data_value": 34.2,
#                 "geolocation_address": "",
#                 "geolocation_zip": "",
#                 "locationid": "49",
#                 "age_years": null,
#                 "geolocation_state": "",
#                 "sample_size": "8719",
#                 "total": "Total",
#                 "stratificationcategory1": "Total",
#                 "high_confidence_limit": "35.5",
#                 "classid": "OWS",
#                 "education": null,
#                 "income": null,
#                 "questionid": "Q037",
#                 "locationdesc": "Utah",
#                 "stratification1": "Total",
#                 "data_value_footnote": null,
#                 "data_value_type": "Value",
#                 "data_value_footnote_symbol": null,
#                 "geolocation_city": "",
#                 "stratificationid1": "OVERALL",
#                 "class": "Obesity / Weight Status",
#                 "datavaluetypeid": "VALUE",
#                 "topic": "Obesity / Weight Status",
#                 "yearend": "2022",
#                 "race_ethnicity": null,
#                 "topicid": "OWS1",
#                 "data_value_alt": "34.2",
#                 "datasource": "BRFSS",
#                 "yearstart": "2022",
#                 "locationabbr": "UT",
#                 "stratificationcategoryid1": "OVR",
#                 "gender": null
#             }
#         },
#         {
#             "type": "Feature",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -78.45789046299967,
#                     37.54268067400045
#                 ]
#             },
#             "properties": {
#                 "question": "Percent of adults aged 18 years and older who have an overweight classification",
#                 "low_confidence_limit": "30.8",
#                 "data_value_unit": null,
#                 "data_value": 32.1,
#                 "geolocation_address": "",
#                 "geolocation_zip": "",
#                 "locationid": "51",
#                 "age_years": null,
#                 "geolocation_state": "",
#                 "sample_size": "9378",
#                 "total": "Total",
#                 "stratificationcategory1": "Total",
#                 "high_confidence_limit": "33.5",
#                 "classid": "OWS",
#                 "education": null,
#                 "income": null,
#                 "questionid": "Q037",
#                 "locationdesc": "Virginia",
#                 "stratification1": "Total",
#                 "data_value_footnote": null,
#                 "data_value_type": "Value",
#                 "data_value_footnote_symbol": null,
#                 "geolocation_city": "",
#                 "stratificationid1": "OVERALL",
#                 "class": "Obesity / Weight Status",
#                 "datavaluetypeid": "VALUE",
#                 "topic": "Obesity / Weight Status",
#                 "yearend": "2022",
#                 "race_ethnicity": null,
#                 "topicid": "OWS1",
#                 "data_value_alt": "32.1",
#                 "datasource": "BRFSS",
#                 "yearstart": "2022",
#                 "locationabbr": "VA",
#                 "stratificationcategoryid1": "OVR",
#                 "gender": null
#             }
#         },
#         {
#             "type": "Feature",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -64.896335,
#                     18.335765
#                 ]
#             },
#             "properties": {
#                 "question": "Percent of adults aged 18 years and older who have an overweight classification",
#                 "low_confidence_limit": "30.1",
#                 "data_value_unit": null,
#                 "data_value": 37.0,
#                 "geolocation_address": "",
#                 "geolocation_zip": "",
#                 "locationid": "78",
#                 "age_years": null,
#                 "geolocation_state": "",
#                 "sample_size": "1394",
#                 "total": "Total",
#                 "stratificationcategory1": "Total",
#                 "high_confidence_limit": "44.5",
#                 "classid": "OWS",
#                 "education": null,
#                 "income": null,
#                 "questionid": "Q037",
#                 "locationdesc": "Virgin Islands",
#                 "stratification1": "Total",
#                 "data_value_footnote": null,
#                 "data_value_type": "Value",
#                 "data_value_footnote_symbol": null,
#                 "geolocation_city": "",
#                 "stratificationid1": "OVERALL",
#                 "class": "Obesity / Weight Status",
#                 "datavaluetypeid": "VALUE",
#                 "topic": "Obesity / Weight Status",
#                 "yearend": "2022",
#                 "race_ethnicity": null,
#                 "topicid": "OWS1",
#                 "data_value_alt": "37.0",
#                 "datasource": "BRFSS",
#                 "yearstart": "2022",
#                 "locationabbr": "VI",
#                 "stratificationcategoryid1": "OVR",
#                 "gender": null
#             }
#         },
#         {
#             "type": "Feature",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -72.51764079099962,
#                     43.62538123900049
#                 ]
#             },
#             "properties": {
#                 "question": "Percent of adults aged 18 years and older who have an overweight classification",
#                 "low_confidence_limit": "32.6",
#                 "data_value_unit": null,
#                 "data_value": 34.1,
#                 "geolocation_address": "",
#                 "geolocation_zip": "",
#                 "locationid": "50",
#                 "age_years": null,
#                 "geolocation_state": "",
#                 "sample_size": "7768",
#                 "total": "Total",
#                 "stratificationcategory1": "Total",
#                 "high_confidence_limit": "35.6",
#                 "classid": "OWS",
#                 "education": null,
#                 "income": null,
#                 "questionid": "Q037",
#                 "locationdesc": "Vermont",
#                 "stratification1": "Total",
#                 "data_value_footnote": null,
#                 "data_value_type": "Value",
#                 "data_value_footnote_symbol": null,
#                 "geolocation_city": "",
#                 "stratificationid1": "OVERALL",
#                 "class": "Obesity / Weight Status",
#                 "datavaluetypeid": "VALUE",
#                 "topic": "Obesity / Weight Status",
#                 "yearend": "2022",
#                 "race_ethnicity": null,
#                 "topicid": "OWS1",
#                 "data_value_alt": "34.1",
#                 "datasource": "BRFSS",
#                 "yearstart": "2022",
#                 "locationabbr": "VT",
#                 "stratificationcategoryid1": "OVR",
#                 "gender": null
#             }
#         },
#         {
#             "type": "Feature",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -120.47001078999972,
#                     47.52227862900048
#                 ]
#             },
#             "properties": {
#                 "question": "Percent of adults aged 18 years and older who have an overweight classification",
#                 "low_confidence_limit": "33.7",
#                 "data_value_unit": null,
#                 "data_value": 34.6,
#                 "geolocation_address": "",
#                 "geolocation_zip": "",
#                 "locationid": "53",
#                 "age_years": null,
#                 "geolocation_state": "",
#                 "sample_size": "22869",
#                 "total": "Total",
#                 "stratificationcategory1": "Total",
#                 "high_confidence_limit": "35.4",
#                 "classid": "OWS",
#                 "education": null,
#                 "income": null,
#                 "questionid": "Q037",
#                 "locationdesc": "Washington",
#                 "stratification1": "Total",
#                 "data_value_footnote": null,
#                 "data_value_type": "Value",
#                 "data_value_footnote_symbol": null,
#                 "geolocation_city": "",
#                 "stratificationid1": "OVERALL",
#                 "class": "Obesity / Weight Status",
#                 "datavaluetypeid": "VALUE",
#                 "topic": "Obesity / Weight Status",
#                 "yearend": "2022",
#                 "race_ethnicity": null,
#                 "topicid": "OWS1",
#                 "data_value_alt": "34.6",
#                 "datasource": "BRFSS",
#                 "yearstart": "2022",
#                 "locationabbr": "WA",
#                 "stratificationcategoryid1": "OVR",
#                 "gender": null
#             }
#         },
#         {
#             "type": "Feature",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -89.81637074199966,
#                     44.39319117400049
#                 ]
#             },
#             "properties": {
#                 "question": "Percent of adults aged 18 years and older who have an overweight classification",
#                 "low_confidence_limit": "31.7",
#                 "data_value_unit": null,
#                 "data_value": 33.0,
#                 "geolocation_address": "",
#                 "geolocation_zip": "",
#                 "locationid": "55",
#                 "age_years": null,
#                 "geolocation_state": "",
#                 "sample_size": "10080",
#                 "total": "Total",
#                 "stratificationcategory1": "Total",
#                 "high_confidence_limit": "34.2",
#                 "classid": "OWS",
#                 "education": null,
#                 "income": null,
#                 "questionid": "Q037",
#                 "locationdesc": "Wisconsin",
#                 "stratification1": "Total",
#                 "data_value_footnote": null,
#                 "data_value_type": "Value",
#                 "data_value_footnote_symbol": null,
#                 "geolocation_city": "",
#                 "stratificationid1": "OVERALL",
#                 "class": "Obesity / Weight Status",
#                 "datavaluetypeid": "VALUE",
#                 "topic": "Obesity / Weight Status",
#                 "yearend": "2022",
#                 "race_ethnicity": null,
#                 "topicid": "OWS1",
#                 "data_value_alt": "33.0",
#                 "datasource": "BRFSS",
#                 "yearstart": "2022",
#                 "locationabbr": "WI",
#                 "stratificationcategoryid1": "OVR",
#                 "gender": null
#             }
#         },
#         {
#             "type": "Feature",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -80.71264013499967,
#                     38.66551020200046
#                 ]
#             },
#             "properties": {
#                 "question": "Percent of adults aged 18 years and older who have an overweight classification",
#                 "low_confidence_limit": "31.7",
#                 "data_value_unit": null,
#                 "data_value": 33.4,
#                 "geolocation_address": "",
#                 "geolocation_zip": "",
#                 "locationid": "54",
#                 "age_years": null,
#                 "geolocation_state": "",
#                 "sample_size": "4640",
#                 "total": "Total",
#                 "stratificationcategory1": "Total",
#                 "high_confidence_limit": "35.1",
#                 "classid": "OWS",
#                 "education": null,
#                 "income": null,
#                 "questionid": "Q037",
#                 "locationdesc": "West Virginia",
#                 "stratification1": "Total",
#                 "data_value_footnote": null,
#                 "data_value_type": "Value",
#                 "data_value_footnote_symbol": null,
#                 "geolocation_city": "",
#                 "stratificationid1": "OVERALL",
#                 "class": "Obesity / Weight Status",
#                 "datavaluetypeid": "VALUE",
#                 "topic": "Obesity / Weight Status",
#                 "yearend": "2022",
#                 "race_ethnicity": null,
#                 "topicid": "OWS1",
#                 "data_value_alt": "33.4",
#                 "datasource": "BRFSS",
#                 "yearstart": "2022",
#                 "locationabbr": "WV",
#                 "stratificationcategoryid1": "OVR",
#                 "gender": null
#             }
#         },
#         {
#             "type": "Feature",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -108.10983035299967,
#                     43.23554134300048
#                 ]
#             },
#             "properties": {
#                 "question": "Percent of adults aged 18 years and older who have an overweight classification",
#                 "low_confidence_limit": "33.7",
#                 "data_value_unit": null,
#                 "data_value": 35.6,
#                 "geolocation_address": "",
#                 "geolocation_zip": "",
#                 "locationid": "56",
#                 "age_years": null,
#                 "geolocation_state": "",
#                 "sample_size": "3799",
#                 "total": "Total",
#                 "stratificationcategory1": "Total",
#                 "high_confidence_limit": "37.6",
#                 "classid": "OWS",
#                 "education": null,
#                 "income": null,
#                 "questionid": "Q037",
#                 "locationdesc": "Wyoming",
#                 "stratification1": "Total",
#                 "data_value_footnote": null,
#                 "data_value_type": "Value",
#                 "data_value_footnote_symbol": null,
#                 "geolocation_city": "",
#                 "stratificationid1": "OVERALL",
#                 "class": "Obesity / Weight Status",
#                 "datavaluetypeid": "VALUE",
#                 "topic": "Obesity / Weight Status",
#                 "yearend": "2022",
#                 "race_ethnicity": null,
#                 "topicid": "OWS1",
#                 "data_value_alt": "35.6",
#                 "datasource": "BRFSS",
#                 "yearstart": "2022",
#                 "locationabbr": "WY",
#                 "stratificationcategoryid1": "OVR",
#                 "gender": null
#             }
#         }
#     ],
#     "crs": {
#         "type": "name",
#         "properties": {
#             "name": "urn:ogc:def:crs:OGC:1.3:CRS84"
#         }
#     }
# }
# Modified GeoJSON data has been saved to modified_geojson.geojson
